# %% [markdown]
# # CFS - Location breakdown

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib as plt
import seaborn as sns
import re
import nltk

# %%
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Firstview

# %%
df = pd.read_csv('/Users/rajathadri_as/Documents/CFS_GSC_pages.csv')

# %%
df.head()
# Out:
#                                            Top pages  Clicks  Impressions  \
# 0                 https://www.caravansforsale.co.uk/   31862       977737
# 1  https://www.caravansforsale.co.uk/touring-cara...   18720      1144697
# 2  https://www.caravansforsale.co.uk/static-carav...   17095       861135
# 3       https://www.caravansforsale.co.uk/campervans   11266      1805405
# 4       https://www.caravansforsale.co.uk/motorhomes    9624      1521141
#
#      CTR  Position
# 0  3.26%      7.82
# 1  1.64%      7.64
# 2  1.99%     10.48
# 3  0.62%      7.33
# 4  0.63%      7.25

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Top pages    1000 non-null   object
#  1   Clicks       1000 non-null   int64
#  2   Impressions  1000 non-null   int64
#  3   CTR          1000 non-null   object
#  4   Position     1000 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 39.2+ KB

# %%
df.columns
# Out:
# Index(['Top pages', 'Clicks', 'Impressions', 'CTR', 'Position'], dtype='object')

# %%
df_city = pd.read_csv('/Users/rajathadri_as/Documents/CFS_city.csv')

# %%
df_city.head()
# Out:
#       id             name  country_id  region_id    region_name  region_sigla  \
# 0  31427      Ab Kettleby         219          4  East Midlands           NaN
# 1  31428         Ab Lench         219          9  West Midlands           NaN
# 2  31429      Abbas Combe         219         10     South West           NaN
# 3  31430         Abberley         219          9  West Midlands           NaN
# 4  31431  Abberley Common         219          9  West Midlands           NaN
#
#    county_id     county_name postcode  \
# 0         63  Leicestershire      LE1
# 1         45   Herefordshire    B97 4
# 2         93        Somerset   BA20 1
# 3        111  Worcestershire    WV1 3
# 4         45   Herefordshire    WV1 3
#
#                               city_county_region  ...  description area_code  \
# 0     Ab Kettleby, Leicestershire, East Midlands  ...          NaN     116.0
# 1         Ab Lench, Herefordshire, West Midlands  ...          NaN    1432.0
# ...

# %%
df_city.shape
# Out:
# (30607, 29)

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30607 entries, 0 to 30606
# Data columns (total 29 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  30607 non-null  int64
#  1   name                30607 non-null  object
#  2   country_id          30607 non-null  int64
#  3   region_id           30607 non-null  int64
#  4   region_name         30606 non-null  object
#  5   region_sigla        0 non-null      float64
#  6   county_id           30607 non-null  int64
#  7   county_name         30606 non-null  object
#  8   postcode            29687 non-null  object
#  9   city_county_region  30607 non-null  object
#  10  external_cod        30546 non-null  float64
#  11  rw_keyword          30607 non-null  object
#  12  old_rw_keyword      30546 non-null  object
#  13  import_keyword      30607 non-null  object
#  14  import_id           30607 non-null  int64
# ...

# %%
df_county = pd.read_csv('/Users/rajathadri_as/Documents/CFS_county.csv')

# %%
df_county.head()
# Out:
#    id  location_id  country_id  region_id region_name           name  \
# 0   1            0         219          6    Scotland  Aberdeenshire
# 1   2            0         219          6    Scotland          Angus
# 2   3            0         219          6    Scotland    Argyllshire
# 3   4            0         219         10  South West           Avon
# 4   5            0         219          6    Scotland       Ayrshire
#
#    other_names            county_region     rw_keyword old_rw_keyword  ...  \
# 0          NaN  Aberdeenshire, Scotland  aberdeenshire            NaN  ...
# 1          NaN          Angus, Scotland          angus            NaN  ...
# 2          NaN    Argyllshire, Scotland    argyllshire            NaN  ...
# 3          NaN         Avon, South West           avon            NaN  ...
# 4          NaN       Ayrshire, Scotland       ayrshire            NaN  ...
#
#    official_code  central_id  img_path img_width  img_height  status  \
# ...

# %%
df_county.shape
# Out:
# (190, 25)

# %%
df_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 190 entries, 0 to 189
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              190 non-null    int64
#  1   location_id     190 non-null    int64
#  2   country_id      190 non-null    int64
#  3   region_id       190 non-null    int64
#  4   region_name     190 non-null    object
#  5   name            190 non-null    object
#  6   other_names     0 non-null      float64
#  7   county_region   190 non-null    object
#  8   rw_keyword      190 non-null    object
#  9   old_rw_keyword  2 non-null      object
#  10  cities_count    190 non-null    int64
#  11  lat_decimal     190 non-null    float64
#  12  long_decimal    190 non-null    float64
#  13  description     1 non-null      object
#  14  import_id       190 non-null    int64
#  15  official_code   0 non-null      float64
#  16  central_id      190 non-null    int64
# ...

# %%
df_region = pd.read_csv('/Users/rajathadri_as/Documents/CFS_region.csv')

# %%
df_region.head()
# Out:
#    id  country_id           name  other_names  sigla  lat_decimal  \
# 0   1         219        Eastern          NaN    NaN    50.984872
# 1   2         219     North East          NaN    NaN    55.378051
# 2   3         219          Wales          NaN    NaN    52.130661
# 3   4         219  East Midlands          NaN    NaN    52.821632
# 4   5         219        Ireland          NaN    NaN    53.412910
#
#    long_decimal  description img_path  img_width  ...  import_id  \
# 0     -1.305332          NaN      NaN          0  ...          0
# 1     -3.435973          NaN      NaN          0  ...          0
# 2     -3.783712          NaN      NaN          0  ...          0
# 3     -1.147234          NaN      NaN          0  ...          0
# 4     -8.243890          NaN      NaN          0  ...          0
#
#    gmap_search_term  official_code central_id   region_sigla  status  \
# 0           England            NaN          0        Eastern       1
# ...

# %%
df_region.shape
# Out:
# (17, 25)

# %%
df_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                17 non-null     int64
#  1   country_id        17 non-null     int64
#  2   name              17 non-null     object
#  3   other_names       0 non-null      float64
#  4   sigla             0 non-null      float64
#  5   lat_decimal       16 non-null     float64
#  6   long_decimal      16 non-null     float64
#  7   description       0 non-null      float64
#  8   img_path          1 non-null      object
#  9   img_width         17 non-null     int64
#  10  img_height        17 non-null     int64
#  11  shape             0 non-null      float64
#  12  old_rw_keyword    0 non-null      float64
#  13  rw_keyword        17 non-null     object
#  14  spotlights        1 non-null      float64
#  15  import_id         17 non-null     int64
# ...

# %% [markdown]
# ### Data Wrangling

# %%
df['CTR'] = df['CTR'].str.replace('%','')

# %%
df['CTR'] = df['CTR'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Top pages    1000 non-null   object
#  1   Clicks       1000 non-null   int64
#  2   Impressions  1000 non-null   int64
#  3   CTR          1000 non-null   float64
#  4   Position     1000 non-null   float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 39.2+ KB

# %%
df.head()
# Out:
#                                            Top pages  Clicks  Impressions  \
# 0                 https://www.caravansforsale.co.uk/   31862       977737
# 1  https://www.caravansforsale.co.uk/touring-cara...   18720      1144697
# 2  https://www.caravansforsale.co.uk/static-carav...   17095       861135
# 3       https://www.caravansforsale.co.uk/campervans   11266      1805405
# 4       https://www.caravansforsale.co.uk/motorhomes    9624      1521141
#
#     CTR  Position
# 0  3.26      7.82
# 1  1.64      7.64
# 2  1.99     10.48
# 3  0.62      7.33
# 4  0.63      7.25

# %%
# df_locality['region'].value_counts()

# %%
# df_locality[df_locality['region']== ' '].head()

# %%
# df_locality[df_locality['city']==' Oakham'].head()

# %%
# df_locality['county'][df_locality['city'] == ' Oakham'] = 'Lestershire'
# df_locality['region'][df_locality['city'] == ' Oakham'] = 'East Midlands'

# %%
# df_locality[df_locality['city']== ' Oakham']

# %%
# df_locality['city'] = df_locality['city'].str.replace(' ','')

# %%
# df_locality['locality'] = df_locality['locality'].str.replace(' ','')

# %%
# df_locality['county'] = df_locality['county'].str.replace(' ','')

# %%
# df_locality['region'] = df_locality['region'].str.replace(' ','')

# %%
df_city = df_city[['id','name']]
df_city.head()
# Out:
#       id             name
# 0  31427      Ab Kettleby
# 1  31428         Ab Lench
# 2  31429      Abbas Combe
# 3  31430         Abberley
# 4  31431  Abberley Common

# %%
df_county = df_county[['id','name']]
df_county.head()
# Out:
#    id           name
# 0   1  Aberdeenshire
# 1   2          Angus
# 2   3    Argyllshire
# 3   4           Avon
# 4   5       Ayrshire

# %%
df_region = df_region[['id','name']]
df_region.head()
# Out:
#    id           name
# 0   1        Eastern
# 1   2     North East
# 2   3          Wales
# 3   4  East Midlands
# 4   5        Ireland

# %%
df_city = df_city.apply(lambda x: x.astype(str).str.lower())
df_city.head()
# Out:
#       id             name
# 0  31427      ab kettleby
# 1  31428         ab lench
# 2  31429      abbas combe
# 3  31430         abberley
# 4  31431  abberley common

# %%
df_county = df_county.apply(lambda x: x.astype(str).str.lower())

# %%
df_region = df_region.apply(lambda x: x.astype(str).str.lower())

# %%
df_city.rename(columns={'name':'city'}, inplace=True)

# %%
df_county.rename(columns={'name':'county'}, inplace=True)

# %%
df_region.rename(columns={'name':'region'}, inplace=True)

# %%
df.head()
# Out:
#                                            Top pages  Clicks  Impressions  \
# 0                 https://www.caravansforsale.co.uk/   31862       977737
# 1  https://www.caravansforsale.co.uk/touring-cara...   18720      1144697
# 2  https://www.caravansforsale.co.uk/static-carav...   17095       861135
# 3       https://www.caravansforsale.co.uk/campervans   11266      1805405
# 4       https://www.caravansforsale.co.uk/motorhomes    9624      1521141
#
#     CTR  Position
# 0  3.26      7.82
# 1  1.64      7.64
# 2  1.99     10.48
# 3  0.62      7.33
# 4  0.63      7.25

# %%
df['Top pages'] = df['Top pages'].str.split('/')

# %%
df['len'] = df['Top pages'].str.len()

# %%
df.head()
# Out:
#                                            Top pages  Clicks  Impressions  \
# 0            [https:, , www.caravansforsale.co.uk, ]   31862       977737
# 1  [https:, , www.caravansforsale.co.uk, touring-...   18720      1144697
# 2  [https:, , www.caravansforsale.co.uk, static-c...   17095       861135
# 3  [https:, , www.caravansforsale.co.uk, campervans]   11266      1805405
# 4  [https:, , www.caravansforsale.co.uk, motorhomes]    9624      1521141
#
#     CTR  Position  len
# 0  3.26      7.82    4
# 1  1.64      7.64    4
# 2  1.99     10.48    5
# 3  0.62      7.33    4
# 4  0.63      7.25    4

# %%
df['Top pages'] = df['Top pages'].str[3:]

# %%
df['len'] = df['Top pages'].str.len()

# %%
df['location1'] = df['Top pages'].str[1]

# %%
df['location2'] = df['Top pages'].str[2]

# %%
df.head()
# Out:
#                     Top pages  Clicks  Impressions   CTR  Position  len  \
# 0                          []   31862       977737  3.26      7.82    1
# 1          [touring-caravans]   18720      1144697  1.64      7.64    1
# 2  [static-caravans, On-site]   17095       861135  1.99     10.48    2
# 3                [campervans]   11266      1805405  0.62      7.33    1
# 4                [motorhomes]    9624      1521141  0.63      7.25    1
#
#   location1 location2
# 0       NaN       NaN
# 1       NaN       NaN
# 2   On-site       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
df['location1'].value_counts()
# Out:
# location1
# swift                                                           68
# elddis                                                          51
# bailey                                                          38
# auto-trail                                                      26
# lunar                                                           21
# coachman                                                        20
# willerby                                                        19
# auto-sleeper                                                    18
# abi                                                             18
# 2-berth                                                         17
# hymer                                                           14
# adria                                                           13
# On-site                                                         11
# chausson                                                        11
# ...

# %%
df['location2'].value_counts()
# Out:
# location2
# 2000-2009                             34
# 2-berth                               34
# 2010-2013                             26
# 4-berth                               24
# 6-berth                               21
# 1990-1999                              8
# 3-berth                                8
# scotland                               7
# 5-berth                                7
# south-west                             6
# new                                    6
# wales                                  5
# buying                                 4
# ownership                              3
# cornwall                               3
# south-east                             2
# Teardrop                               2
# norfolk                                2
# north-west                             2
# north-east                             2
# elddis-avante-550                      1
# atlantic-caravans                      1
# ...

# %%
df['len_l1'] = df['location1'].str.len()
df['len_l2'] = df['location2'].str.len()

# %%
df.shape
# Out:
# (1000, 10)

# %%
df
# Out:
#                                              Top pages  Clicks  Impressions  \
# 0                                                   []   31862       977737
# 1                                   [touring-caravans]   18720      1144697
# 2                           [static-caravans, On-site]   17095       861135
# 3                                         [campervans]   11266      1805405
# 4                                         [motorhomes]    9624      1521141
# 5                          [touring-caravans, 2-berth]    6666       486904
# 6                          [static-caravans, scotland]    6237       212413
# 7                                    [static-caravans]    6216       835919
# 8                            [touring-caravans, eriba]    5105       409191
# 9                             [static-caravans, wales]    4571       303081
# 10                                    [campervans, vw]    4510       652778
# ...

# %%
df = df[df['len']<=3]

# %%
list(df[df['len']==3]['Top pages'])
# Out:
# [['static-caravans', 'abi', 'abi-ambleside'],
#  ['static-caravans', 'swift', 'swift-bordeaux'],
#  ['touring-caravans', 'swift', '2-berth'],
#  ['static-caravans', 'abi', 'abi-beaumont'],
#  ['touring-caravans', 'elddis', '6-berth'],
#  ['touring-caravans', 'lunar', 'lunar-ariva'],
#  ['touring-caravans', 'pennine', 'pathfinder'],
#  ['static-caravans', 'abi', 'oakley'],
#  ['static-caravans', 'willerby', 'willerby-rio-gold'],
#  ['motorhomes', 'auto-sleeper', 'auto-sleeper-nuevo-ek'],
#  ['touring-caravans', 'coachman', 'coachman-vip-575'],
#  ['touring-caravans', 'coachman', '2-berth'],
#  ['touring-caravans', 'swift', '6-berth'],
#  ['motorhomes', 'romahome', 'r30'],
#  ['touring-caravans', 'elddis', '2-berth'],
#  ['static-caravans', 'willerby', 'willerby-avonmore'],
#  ['touring-caravans', 'buccaneer', 'barracuda'],
#  ['static-caravans', 'willerby', '2000-2009'],
#  ['static-caravans', 'On-site', 'cornwall'],
#  ['motorhomes', 'auto-trail', 'v-line'],
# ...

# %%
df_1 = df[df['len_l1'] <=26]

# %%
df_1 = df_1[df_1['len_l2'].isnull()]

# %%
df_1.reset_index(drop=True, inplace=True)

# %%
df_2 = df[df['len_l2'] <=32]

# %%
df_2.reset_index(drop=True, inplace=True)

# %%
df_1 = df_1[['Top pages','Clicks','location1']]
df_2 = df_2[['Top pages','Clicks','location2']]

# %%
df_1.rename(columns={'location1':'location'}, inplace=True)
df_2.rename(columns={'location2':'location'}, inplace=True)

# %%
df_1.shape
# Out:
# (505, 3)

# %%
df_2.shape
# Out:
# (457, 3)

# %%
df = pd.concat([df_1, df_2], axis=0)

# %%
df.shape
# Out:
# (962, 3)

# %%
df = df[df['location'].str.len() != 0]

# %%
df = df[df['location'] != 'ads_new.php']

# %%
df = df[df['location'] != 'business']

# %%
df.reset_index(inplace=True,drop=True)

# %%
df.head()
# Out:
#                      Top pages  Clicks  location
# 0   [static-caravans, On-site]   17095   On-site
# 1  [touring-caravans, 2-berth]    6666   2-berth
# 2  [static-caravans, scotland]    6237  scotland
# 3    [touring-caravans, eriba]    5105     eriba
# 4     [static-caravans, wales]    4571     wales

# %%
df_locnew = pd.pivot_table(df,index='location',values='Clicks', aggfunc=np.sum)

# %%
df_locnew.reset_index(inplace=True, drop=False)

# %%
df_locnew
# Out:
#                             location  Clicks
# 0                            1-berth     583
# 1                            1261276     102
# 2                            1304261     150
# 3                            1325115     209
# 4                            1346744     103
# 5                            1357511     121
# 6                            1380601     106
# 7                            1396039     134
# 8                          1970-1979     237
# 9                          1980-1989     267
# 10                         1990-1999    3491
# 11                           2-berth   21618
# 12                         2000-2009   10739
# 13                         2010-2013    6052
# 14                           3-berth    3911
# 15                           4-berth    9556
# 16                              400l     181
# 17                           5-berth    3255
# 18             5-best-small-caravans     184
# 19                         5th-Wheel    1304
# ...

# %%
df_locnew.shape
# Out:
# (597, 2)

# %%
df_city = df_city.reset_index(drop=True)

# %%
df_city['city'] = df_city['city'].str.replace("'", '')
df_city['city'] = df_city['city'].str.replace('-','')
df_city['city'] = df_city['city'].str.replace('.','')

# %%
df_city.head(80)
# Out:
#        id               city
# 0   31427        ab kettleby
# 1   31428           ab lench
# 2   31429        abbas combe
# 3   31430           abberley
# 4   31431    abberley common
# 5   31432           abberton
# 6   31433           abberton
# 7   31434          abberwick
# 8   31435      abbess roding
# 9   31436              abbey
# 10  31437         abbey dore
# 11  31438        abbey green
# 12  31439         abbey hill
# 13  31440   abbey st bathans
# 14  31441         abbey town
# 15  31442      abbey village
# 16  31443         abbey wood
# 17  31444        abbeycwmhir
# 18  31445          abbeydale
# 19  31446         abbeylands
# 20  31447         abbeystead
# 21  31448       abbots chair
# 22  31449     abbots salford
# 23  31450          abbotrule
# 24  31451  abbots bickington
# 25  31452     abbots bromley
# 26  31453     abbots deuglie
# 27  31454     abbots langley
# 28  31455       abbots leigh
# 29  31456      abbots morton
# 30  31457      abbots ripton
# ...

# %%
df_county['county'] = df_county['county'].str.replace("'", '')
df_county['county'] = df_county['county'].str.replace('-','')
df_county['county'] = df_county['county'].str.replace('.','')

# %%
df_county = df_county.reset_index(drop=True)

# %%
df_county.head(80)
# Out:
#     id              county
# 0    1       aberdeenshire
# 1    2               angus
# 2    3         argyllshire
# 3    4                avon
# 4    5            ayrshire
# 5    6          banffshire
# 6    7        bedfordshire
# 7    8           berkshire
# 8    9        berwickshire
# 9   10    scottish borders
# 10  11             bristol
# 11  12     buckinghamshire
# 12  13           caithness
# 13  14      cambridgeshire
# 14  16            cheshire
# 15  17    clackmannanshire
# 16  18           cleveland
# 17  19               clwyd
# 18  20           co durham
# 19  21               conwy
# 20  22            cornwall
# 21  23             cumbria
# 22  24          derbyshire
# 23  25               devon
# 24  26              dorset
# 25  27       dumfriesshire
# 26  28      dunbartonshire
# 27  29              durham
# 28  30               dyfed
# 29  31        east lothian
# 30  32         east sussex
# 31  33           edinburgh
# 32  34               essex
# ...

# %%
df_region['region'] = df_region['region'].str.replace("'", '')
df_region['region'] = df_region['region'].str.replace('-','')
df_region['region'] = df_region['region'].str.replace('.','')
df_region['region'] = df_region['region'].str.replace(',','')

# %%
df_region = df_region.reset_index(drop=True)

# %%
df_region.head(80)
# Out:
#     id            region
# 0    1           eastern
# 1    2        north east
# 2    3             wales
# 3    4     east midlands
# 4    5           ireland
# 5    6          scotland
# 6    7          overseas
# 7    8     thames valley
# 8    9     west midlands
# 9   10        south west
# 10  11       isle of man
# 11  12   channel islands
# 12  13        north west
# 13  14        south east
# 14  15  northern ireland
# 15  16  southern ireland
# 16  83        kirriemuir

# %%
# df_locality['locality'] = df_locality['locality'].str.replace(' ','')
df_city['city'] = df_city['city'].str.replace(' ','')
df_county['county'] = df_county['county'].str.replace(' ','')
df_region['region'] = df_region['region'].str.replace(' ','')

# %%
df_locnew.shape
# Out:
# (597, 2)

# %%
df_locnew['location'] = df_locnew['location'].str.replace('-','')

# %%
df_locnew
# Out:
#                         location  Clicks
# 0                         1berth     583
# 1                        1261276     102
# 2                        1304261     150
# 3                        1325115     209
# 4                        1346744     103
# 5                        1357511     121
# 6                        1380601     106
# 7                        1396039     134
# 8                       19701979     237
# 9                       19801989     267
# 10                      19901999    3491
# 11                        2berth   21618
# 12                      20002009   10739
# 13                      20102013    6052
# 14                        3berth    3911
# 15                        4berth    9556
# 16                          400l     181
# 17                        5berth    3255
# 18            5bestsmallcaravans     184
# 19                      5thWheel    1304
# 20                        6berth   14217
# 21                        7berth    1329
# ...

# %%
# df_locnew = pd.merge(df_locnew, df_locality[['locality']], how='left', left_on='location', right_on='locality')

# %%
# df_locnew.head()

# %%
# df_locnew.shape

# %%
# df_locnew[df_locnew.duplicated()].count()

# %%
# df_locnew['category'] = df_locnew['locality'].apply(lambda x: 'locality' if pd.notna(x) else None)

# %%
# df_locnew.head()

# %%
df_locnew = pd.merge(df_locnew, df_city[['city']], how='left', left_on='location', right_on='city')

# %%
df_locnew
# Out:
#                         location  Clicks               city
# 0                         1berth     583                NaN
# 1                        1261276     102                NaN
# 2                        1304261     150                NaN
# 3                        1325115     209                NaN
# 4                        1346744     103                NaN
# 5                        1357511     121                NaN
# 6                        1380601     106                NaN
# 7                        1396039     134                NaN
# 8                       19701979     237                NaN
# 9                       19801989     267                NaN
# 10                      19901999    3491                NaN
# 11                        2berth   21618                NaN
# 12                      20002009   10739                NaN
# 13                      20102013    6052                NaN
# 14                        3berth    3911                NaN
# ...

# %%
df_locnew['category'] = df_locnew.apply(lambda row: 'city' if pd.notna(row['city']) else None, axis=1)

# %%
df_locnew
# Out:
#                         location  Clicks               city category
# 0                         1berth     583                NaN     None
# 1                        1261276     102                NaN     None
# 2                        1304261     150                NaN     None
# 3                        1325115     209                NaN     None
# 4                        1346744     103                NaN     None
# 5                        1357511     121                NaN     None
# 6                        1380601     106                NaN     None
# 7                        1396039     134                NaN     None
# 8                       19701979     237                NaN     None
# 9                       19801989     267                NaN     None
# 10                      19901999    3491                NaN     None
# 11                        2berth   21618                NaN     None
# 12                      20002009   10739                NaN     None
# ...

# %%
df_locnew = pd.merge(df_locnew, df_county[['county']], how='left', left_on='location', right_on='county')
df_locnew['category'] = df_locnew.apply(lambda row: 'county' if pd.notna(row['county']) else row['category'], axis=1)

# %%
# Step 4: Merge df_locnew with df_region
df_locnew = pd.merge(df_locnew, df_region[['region']], how='left', left_on='location', right_on='region')
df_locnew['category'] = df_locnew.apply(lambda row: 'region' if pd.notna(row['region']) else row['category'], axis=1)

# %%
df_locnew
# Out:
#                         location  Clicks               city category  \
# 0                         1berth     583                NaN     None
# 1                        1261276     102                NaN     None
# 2                        1304261     150                NaN     None
# 3                        1325115     209                NaN     None
# 4                        1346744     103                NaN     None
# 5                        1357511     121                NaN     None
# 6                        1380601     106                NaN     None
# 7                        1396039     134                NaN     None
# 8                       19701979     237                NaN     None
# 9                       19801989     267                NaN     None
# 10                      19901999    3491                NaN     None
# 11                        2berth   21618                NaN     None
# 12                      20002009   10739                NaN     None
# ...

# %%
# Step 5: Drop the extra columns from the merges
df_locnew = df_locnew.drop(columns=['city', 'county', 'region'])

# %%
df.head()
# Out:
#                      Top pages  Clicks  location
# 0   [static-caravans, On-site]   17095   On-site
# 1  [touring-caravans, 2-berth]    6666   2-berth
# 2  [static-caravans, scotland]    6237  scotland
# 3    [touring-caravans, eriba]    5105     eriba
# 4     [static-caravans, wales]    4571     wales

# %%
df[df['location'].str.contains('')]
# Out:
#                               Top pages  Clicks         location
# 204  [static-caravans, weymouth-dorset]     270  weymouth-dorset

# %%
df_locnew
# Out:
#                         location  Clicks category
# 0                         1berth     583     None
# 1                        1261276     102     None
# 2                        1304261     150     None
# 3                        1325115     209     None
# 4                        1346744     103     None
# 5                        1357511     121     None
# 6                        1380601     106     None
# 7                        1396039     134     None
# 8                       19701979     237     None
# 9                       19801989     267     None
# 10                      19901999    3491     None
# 11                        2berth   21618     None
# 12                      20002009   10739     None
# 13                      20102013    6052     None
# 14                        3berth    3911     None
# 15                        4berth    9556     None
# 16                          400l     181     None
# 17                        5berth    3255     None
# ...

# %%
df_locnew.loc[df_locnew.location == 'ashfordkent', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'barnsleysouthyorkshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'birminghamwestmidlands', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'blackpoollancashire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'boltongreatermanchester', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'bradfordwestyorkshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'braintreeessex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'brightoneastsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'burygreatermanchester', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'buxtonderbyshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'carlislecumbria', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'cheltenhamgloucestershire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'chestercheshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'chesterfieldderbyshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'chichesterwestsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'colchesteressex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'coventrywestmidlands', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'crawleywestsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'crewecheshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'cromernorfolk', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'eastbourneeastsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'exeterdevon', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'uk', 'category'] = "uk"
df_locnew.loc[df_locnew.location == 'glasgowstrathclyde', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'hastingseastsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'hinckleyleicestershire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'horshamwestsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'huddersfield?page=3', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'invernesshighland', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'ipswichsuffolk', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'lancasterlancashire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'leedswestyorkshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'leicesterleicestershire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'lincolnlincolnshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'liverpoolmerseyside', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'mansfieldnottinghamshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'minsterkent', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'narberthpembrokeshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'niesmannandbischoff', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'norwichnorfolk', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'peeblesscottishborders', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'pontefract?page=3', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'portsmouthhampshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'ringwoodhampshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'riponnorthyorkshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'ryeeastsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'seafordeastsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'selbynorthyorkshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'sheffieldsouthyorkshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'skegness?page=3', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'southamptonsoutheast', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'southportmerseyside', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'spaldinglincolnshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'sthelensmerseyside', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'swanseawestglamorgan', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'telfordshropshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'timberland', 'category'] = None
df_locnew.loc[df_locnew.location == 'warringtoncheshire', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'westmidlandswm', 'category'] = "county"
df_locnew.loc[df_locnew.location == 'weymouthdorset', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'worthingwestsussex', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'yorknorthyorkshire', 'category'] = "city"

# %%
df_locnew.isna().sum()
# Out:
# location      0
# Clicks        0
# category    376
# dtype: int64

# %%
df_locnew.shape
# Out:
# (597, 3)

# %%
df_locnew.drop_duplicates(keep='first', inplace=True)

# %%
df_locnew[df_locnew['category'].isnull()]
# Out:
#                         location  Clicks category
# 0                         1berth     583     None
# 1                        1261276     102     None
# 2                        1304261     150     None
# 3                        1325115     209     None
# 4                        1346744     103     None
# 5                        1357511     121     None
# 6                        1380601     106     None
# 7                        1396039     134     None
# 8                       19701979     237     None
# 9                       19801989     267     None
# 10                      19901999    3491     None
# 11                        2berth   21618     None
# 12                      20002009   10739     None
# 13                      20102013    6052     None
# 14                        3berth    3911     None
# 15                        4berth    9556     None
# 16                          400l     181     None
# 17                        5berth    3255     None
# ...

# %%
df_locnew.dropna(inplace=True)

# %%
df_locnew.reset_index(drop=True, inplace=True)

# %%
df_locnew
# Out:
#                       location  Clicks category
# 0                        abbey     367     city
# 1                aberdeenshire     280   county
# 2                     abersoch     191     city
# 3                  aberystwyth     110     city
# 4                   allhallows     690     city
# 5                       amroth     400     city
# 6                  ashfordkent     264     city
# 7                     barmouth     533     city
# 8                barnardcastle     128     city
# 9       barnsleysouthyorkshire     327     city
# 10                  barnstaple     292     city
# 11                 basingstoke     167     city
# 12                bedfordshire     147   county
# 13            berwickupontweed     126     city
# 14                   bessacarr    1111     city
# 15                    beverley     387     city
# 16                 birchington     124     city
# 17      birminghamwestmidlands     228     city
# 18         blackpoollancashire     290     city
# ...

# %%
df_locnew.to_clipboard(excel=True)

# %%
pd.pivot_table(df_locnew, index=['category'], values='Clicks', aggfunc=np.sum)
# Out:
#           Clicks
# category
# city       54146
# county     26282
# region     26237

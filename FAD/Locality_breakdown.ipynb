# %% [markdown]
# # FAD - Location breakdown

# %%
import pandas as pd
import numpy as np
import warnings
import matplotlib as plt
import seaborn as sns
import re
import nltk

# %%
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Firstview

# %% [markdown]
# Main DF

# %%
df = pd.read_csv('/Users/rajathadri_as/Documents/FAD_GSC_pages.csv')

# %% [markdown]
# Animals only

# %%
df = pd.read_csv('/Users/rajathadri_as/Documents/FAD_GSC_Animals_Pages.csv')

# %% [markdown]
# New DF

# %%
df = pd.read_csv('/Users/rajathadri_as/Documents/FAD_GSC_Looker2.csv')

# %%
df.rename(columns={'Landing Page':'Top pages','Url Clicks':'Clicks'}, inplace = True)

# %% [markdown]
# ... Continued

# %%
df.head()
# Out:
#           Date      Query                     Top pages  Clicks
# 0  5 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1377
# 1  4 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1211
# 2  2 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1197
# 3  30 Aug 2024  friday ad  https://www.friday-ad.co.uk/    1184
# 4  3 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1181

# %%
df.shape
# Out:
# (750000, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       750000 non-null  object
#  1   Query      750000 non-null  object
#  2   Top pages  750000 non-null  object
#  3   Clicks     750000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 22.9+ MB

# %%
df.columns
# Out:
# Index(['Date', 'Query', 'Top pages', 'Clicks'], dtype='object')

# %%
df_locality = pd.read_csv('/Users/rajathadri_as/Documents/FAD_locality.csv')

# %%
df_locality.head()
# Out:
#    id         name                  locality_city_county_region
# 0   1     Hainault     Hainault, London, Greater London, London
# 1   2    Whetstone    Whetstone, London, Greater London, London
# 2   3          Ham          Ham, London, Greater London, London
# 3   4   White City   White City, London, Greater London, London
# 4   5  Hammersmith  Hammersmith, London, Greater London, London

# %%
df_locality.shape
# Out:
# (30529, 3)

# %%
df_locality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30529 entries, 0 to 30528
# Data columns (total 3 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           30529 non-null  int64
#  1   name                         30529 non-null  object
#  2   locality_city_county_region  30529 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 715.7+ KB

# %%
df_city = pd.read_csv('/Users/rajathadri_as/Documents/FAD_city.csv')

# %%
df_city.head()
# Out:
#    id  region_id               region_name  region_sigla  county_id  \
# 0   1          7  Yorkshire and the Humber           NaN        116
# 1   2          4           East of England           NaN        107
# 2   3          8                     North           NaN        117
# 3   4          9                  Scotland           NaN        120
# 4   5         10                     Wales           NaN        119
#
#        county_name  country_id         name postcode  \
# 0  North Yorkshire         219        Ripon      NaN
# 1            Essex         219     Purfleet      NaN
# 2    Tyne And Wear         219      Hebburn      NaN
# 3       Perthshire         219  Crianlarich      NaN
# 4          Gwynedd         219    Llandudno      NaN
#
#                                  city_county_region  ...  area_code  \
# 0  Ripon, North Yorkshire, Yorkshire and the Humber  ...        NaN
# 1                  Purfleet, Essex, East of England  ...        NaN
# ...

# %%
df_city.shape
# Out:
# (1460, 30)

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  1460 non-null   int64
#  1   region_id           1460 non-null   int64
#  2   region_name         1460 non-null   object
#  3   region_sigla        0 non-null      float64
#  4   county_id           1460 non-null   int64
#  5   county_name         1460 non-null   object
#  6   country_id          1460 non-null   int64
#  7   name                1460 non-null   object
#  8   postcode            1 non-null      object
#  9   city_county_region  1460 non-null   object
#  10  external_cod        0 non-null      float64
#  11  rw_keyword          1460 non-null   object
#  12  old_rw_keyword      1427 non-null   object
#  13  import_keyword      23 non-null     object
#  14  import_id           1460 non-null   int64
# ...

# %%
df_county = pd.read_csv('/Users/rajathadri_as/Documents/FAD_county.csv')

# %%
df_county.head()
# Out:
#    id  location_id  country_id  region_id               region_name  \
# 0   1            1         219          9                  Scotland
# 1   2            1         219          9                  Scotland
# 2   3            1         219         11          Northern Ireland
# 3   4            3         219          7  Yorkshire and the Humber
# 4   5            3         219          9                  Scotland
#
#                name  other_names                              county_region  \
# 0     Aberdeenshire          NaN                    Aberdeenshire, Scotland
# 1  Shetland Islands          NaN                 Shetland Islands, Scotland
# 2            Antrim          NaN            County Antrim, Northern Ireland
# 3   South Yorkshire          NaN  South Yorkshire, Yorkshire and the Humber
# 4       Lanarkshire          NaN                      Lanarkshire, Scotland
#
#          rw_keyword    old_rw_keyword  ...  official_code  central_id  \
# ...

# %%
df_county.shape
# Out:
# (121, 25)

# %%
df_county.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              121 non-null    int64
#  1   location_id     121 non-null    int64
#  2   country_id      121 non-null    int64
#  3   region_id       121 non-null    int64
#  4   region_name     121 non-null    object
#  5   name            121 non-null    object
#  6   other_names     0 non-null      float64
#  7   county_region   121 non-null    object
#  8   rw_keyword      121 non-null    object
#  9   old_rw_keyword  115 non-null    object
#  10  cities_count    121 non-null    int64
#  11  lat_decimal     121 non-null    float64
#  12  long_decimal    121 non-null    float64
#  13  description     0 non-null      float64
#  14  import_id       121 non-null    int64
#  15  official_code   0 non-null      float64
#  16  central_id      121 non-null    int64
# ...

# %%
df_region = pd.read_csv('/Users/rajathadri_as/Documents/FAD_region.csv')

# %%
df_region.head()
# Out:
#    id  country_id             name  other_names  sigla  lat_decimal  \
# 0   1         219       South East          NaN    NaN    51.169852
# 1   2         219       South West          NaN    NaN          NaN
# 2   3         219           London          NaN    NaN    51.515282
# 3   4         219  East of England          NaN    NaN          NaN
# 4   5         219    East Midlands          NaN    NaN    53.117114
#
#    long_decimal  description  img_path  img_width  ...  import_id  \
# 0     -0.563734          NaN       NaN          0  ...          0
# 1           NaN          NaN       NaN          0  ...          0
# 2     -0.131134          NaN       NaN          0  ...          0
# 3           NaN          NaN       NaN          0  ...          0
# 4     -0.404603          NaN       NaN          0  ...          0
#
#    gmap_search_term  official_code central_id  region_sigla  status  \
# 0               NaN            NaN          0           NaN       0
# ...

# %%
df_region.shape
# Out:
# (13, 25)

# %%
df_region.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                13 non-null     int64
#  1   country_id        13 non-null     int64
#  2   name              13 non-null     object
#  3   other_names       0 non-null      float64
#  4   sigla             0 non-null      float64
#  5   lat_decimal       6 non-null      float64
#  6   long_decimal      6 non-null      float64
#  7   description       0 non-null      float64
#  8   img_path          0 non-null      float64
#  9   img_width         13 non-null     int64
#  10  img_height        13 non-null     int64
#  11  shape             0 non-null      float64
#  12  old_rw_keyword    0 non-null      float64
#  13  rw_keyword        13 non-null     object
#  14  spotlights        1 non-null      float64
#  15  import_id         13 non-null     int64
# ...

# %% [markdown]
# ### Data Wrangling

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750000 entries, 0 to 749999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       750000 non-null  object
#  1   Query      750000 non-null  object
#  2   Top pages  750000 non-null  object
#  3   Clicks     750000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 22.9+ MB

# %%
df.head()
# Out:
#           Date      Query                     Top pages  Clicks
# 0  5 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1377
# 1  4 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1211
# 2  2 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1197
# 3  30 Aug 2024  friday ad  https://www.friday-ad.co.uk/    1184
# 4  3 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1181

# %%
df_locality.columns
# Out:
# Index(['id', 'name', 'locality_city_county_region'], dtype='object')

# %%
df_locality = df_locality[['id','name']]

# %%
df_locality.head()
# Out:
#    id         name
# 0   1     Hainault
# 1   2    Whetstone
# 2   3          Ham
# 3   4   White City
# 4   5  Hammersmith

# %%
df_locality.isnull().sum()
# Out:
# id      0
# name    0
# dtype: int64

# %%
# df_locality['region'].value_counts()

# %%
# df_locality[df_locality['region']== ' '].head()

# %%
# df_locality[df_locality['city']==' Oakham'].head()

# %%
# df_locality['county'][df_locality['city'] == ' Oakham'] = 'Lestershire'
# df_locality['region'][df_locality['city'] == ' Oakham'] = 'East Midlands'

# %%
# df_locality[df_locality['city']== ' Oakham']

# %%
# df_locality['city'] = df_locality['city'].str.replace(' ','')

# %%
# df_locality['locality'] = df_locality['locality'].str.replace(' ','')

# %%
# df_locality['county'] = df_locality['county'].str.replace(' ','')

# %%
# df_locality['region'] = df_locality['region'].str.replace(' ','')

# %%
df_city = df_city[['id','name']]
df_city.head()
# Out:
#    id         name
# 0   1        Ripon
# 1   2     Purfleet
# 2   3      Hebburn
# 3   4  Crianlarich
# 4   5    Llandudno

# %%
df_county = df_county[['id','name']]
df_county.head()
# Out:
#    id              name
# 0   1     Aberdeenshire
# 1   2  Shetland Islands
# 2   3            Antrim
# 3   4   South Yorkshire
# 4   5       Lanarkshire

# %%
df_region = df_region[['id','name']]
df_region.head()
# Out:
#    id             name
# 0   1       South East
# 1   2       South West
# 2   3           London
# 3   4  East of England
# 4   5    East Midlands

# %%
df_locality = df_locality.apply(lambda x: x.astype(str).str.lower())

# %%
df_locality.head()
# Out:
#   id         name
# 0  1     hainault
# 1  2    whetstone
# 2  3          ham
# 3  4   white city
# 4  5  hammersmith

# %%
df_city = df_city.apply(lambda x: x.astype(str).str.lower())
df_city.head()
# Out:
#   id         name
# 0  1        ripon
# 1  2     purfleet
# 2  3      hebburn
# 3  4  crianlarich
# 4  5    llandudno

# %%
df_county = df_county.apply(lambda x: x.astype(str).str.lower())

# %%
df_region = df_region.apply(lambda x: x.astype(str).str.lower())

# %%
df_locality.rename(columns={'name':'locality'}, inplace=True)

# %%
df_city.rename(columns={'name':'city'}, inplace=True)

# %%
df_county.rename(columns={'name':'county'}, inplace=True)

# %%
df_region.rename(columns={'name':'region'}, inplace=True)

# %%
df.head()
# Out:
#           Date      Query                     Top pages  Clicks
# 0  5 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1377
# 1  4 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1211
# 2  2 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1197
# 3  30 Aug 2024  friday ad  https://www.friday-ad.co.uk/    1184
# 4  3 Sept 2024  friday ad  https://www.friday-ad.co.uk/    1181

# %%
df['Top pages'] = df['Top pages'].str.split('/')

# %%
list(df['Top pages'])
# Out:
# [['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
#  ['https:', '', 'www.friday-ad.co.uk', ''],
# ...

# %%
df['Top pages'] = df['Top pages'].str[3:]

# %%
df['len'] = df['Top pages'].str.len()

# %%
list(df['Top pages'])
# Out:
# [[''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['brighton'],
#  [''],
#  ['eastbourne'],
#  ['brighton'],
#  ['brighton', 'adult-services', 'escorts'],
#  [''],
#  [''],
#  ['brighton'],
#  ['brighton'],
#  ['eastbourne'],
#  ['eastbourne'],
#  ['brighton'],
#  [''],
#  [''],
#  ['eastbourne'],
#  [''],
#  ['brighton'],
#  [''],
#  ['eastbourne'],
#  [''],
#  [''],
#  [''],
#  ['brighton'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['brighton'],
#  [''],
#  [''],
#  ['eastbourne'],
#  [''],
#  ['brighton'],
#  ['brighton', 'adult-services', 'escorts'],
#  ['brighton'],
#  [''],
#  [''],
#  [''],
#  [''],
#  ['eastbourne'],
#  ['brighton', 'adult-services', 'escorts'],
#  [''],
#  ['eastbourne'],
#  ['brighton'],
#  ['brighton'],
#  ['brighton'],
#  [''],
#  [''],
#  [''],
#  ['hastings'],
# ...

# %%
df['location'] = df['Top pages'].str[0]

# %%
df['type'] = df['Top pages'].str[1]

# %%
df['sub-cat'] = df['Top pages'].str[3]

# %%
df.head()
# Out:
#           Date      Query Top pages  Clicks  len location type sub-cat
# 0  5 Sept 2024  friday ad        []    1377    1           NaN     NaN
# 1  4 Sept 2024  friday ad        []    1211    1           NaN     NaN
# 2  2 Sept 2024  friday ad        []    1197    1           NaN     NaN
# 3  30 Aug 2024  friday ad        []    1184    1           NaN     NaN
# 4  3 Sept 2024  friday ad        []    1181    1           NaN     NaN

# %%
df['location'].value_counts()
# Out:
# location
# uk                                                                                                    75476
# business                                                                                              22191
# brighton                                                                                              19914
#                                                                                                       18675
# eastbourne                                                                                            15604
# east-sussex                                                                                           13156
# hastings                                                                                              12506
# crawley                                                                                               11614
# ...

# %%
df['sub-cat'].value_counts()
# Out:
# sub-cat
# dogs-and-puppies                                                                                     24862
# cats-and-kittens                                                                                     15646
# automatic                                                                                            14577
# massages                                                                                              5631
# asian                                                                                                 4742
# caucasian                                                                                             4519
# therapy-services                                                                                      3866
# horses                                                                                                3635
# for-rent                                                                                              3419
# ...

# %%
df['type'].value_counts()
# Out:
# type
# adult-services                                                   341535
# motors                                                            80401
# services                                                          76420
# animals                                                           57498
# for-sale                                                          36166
# properties                                                        10876
# adult-massage                                                      9761
# jobs                                                               9102
# events                                                             7921
# escorts                                                            6647
#                                                                    6000
# other-massage                                                      2325
# health-beauty-wellness                                             1970
# ...

# %%
df['type'] = df['type'].str.split('?').str[0]

# %%
df.shape
# Out:
# (750000, 8)

# %%
df = df[df['location'].str.len() <=22]

# %%
df = df[df['location'].str.len() != 0]

# %%
df = df[df['location'] != 'ads_new.php']

# %%
df = df[df['location'] != 'business']

# %%
categories = 'adult-services|motors|animals|for-sale|properties|jobs'
df = df[df['type'].str.contains(categories, case=False, na=False)]

# %%
df = df[df['type'] != 'motors5']
df = df[df['type'] != 'motors3']
df = df[df['type'] != 'adult-services8']
df = df[df['type'] != 'adult-services0']
df = df[df['type'] != 'adult-services2']
df = df[df['type'] != 'motors&op=adv_search']

# %%
df.reset_index(inplace=True,drop=True)

# %%
df.head()
# Out:
#           Date             Query                            Top pages  Clicks  \
# 0  29 Aug 2024  brighton escorts  [brighton, adult-services, escorts]      96
# 1  30 Aug 2024  brighton escorts  [brighton, adult-services, escorts]      78
# 2  31 Aug 2024  brighton escorts  [brighton, adult-services, escorts]      76
# 3  1 Sept 2024  brighton escorts  [brighton, adult-services, escorts]      68
# 4  5 Sept 2024  brighton escorts  [brighton, adult-services, escorts]      61
#
#    len  location            type sub-cat
# 0    3  brighton  adult-services     NaN
# 1    3  brighton  adult-services     NaN
# 2    3  brighton  adult-services     NaN
# 3    3  brighton  adult-services     NaN
# 4    3  brighton  adult-services     NaN

# %%
df_locnew = pd.pivot_table(df,index=['type','location'],values='Clicks', aggfunc=np.sum)

# %%
df_locnew.head()
# Out:
#                                      Clicks
# type           location
# adult-services abbey-wood                40
#                abbots-langley             4
#                aberdeen                 544
#                aberdeenshire            171
#                abington-northampton       0

# %%
df_locnew.to_clipboard(excel=True)

# %%
df_locnew.reset_index(inplace=True, drop=False)

# %%
df_locnew.head()
# Out:
#              type              location  Clicks
# 0  adult-services            abbey-wood      40
# 1  adult-services        abbots-langley       4
# 2  adult-services              aberdeen     544
# 3  adult-services         aberdeenshire     171
# 4  adult-services  abington-northampton       0

# %%
df_locnew.shape
# Out:
# (5521, 3)

# %%
df_locality['locality'] = df_locality['locality'].str.replace("'", '')
df_locality['locality'] = df_locality['locality'].str.replace('-','')
df_locality['locality'] = df_locality['locality'].str.replace('.','')

# %%
df_locality = df_locality.reset_index(drop=True)

# %%
df_locality.head()
# Out:
#   id     locality
# 0  1     hainault
# 1  2    whetstone
# 2  3          ham
# 3  4   white city
# 4  5  hammersmith

# %%
df_city = df_city.reset_index(drop=True)

# %%
df_city['city'] = df_city['city'].str.replace("'", '')
df_city['city'] = df_city['city'].str.replace('-','')
df_city['city'] = df_city['city'].str.replace('.','')

# %%
df_city.head(80)
# Out:
#     id                city
# 0    1               ripon
# 1    2            purfleet
# 2    3             hebburn
# 3    4         crianlarich
# 4    5           llandudno
# 5    6    saltburnbythesea
# 6    7       knaresborough
# 7    8      westcliffonsea
# 8    9              jarrow
# 9   10              killin
# 10  11  llandudno junction
# 11  12         guisborough
# 12  13           tadcaster
# 13  14       southendonsea
# 14  15       south shields
# 15  16               perth
# 16  17               conwy
# 17  18                yarm
# 18  19                york
# 19  20            wickford
# 20  21     boldon colliery
# 21  22         blairgowrie
# 22  23      llanfairfechan
# 23  24      stocktonontees
# 24  25            aberdeen
# 25  26         scarborough
# 26  27            basildon
# 27  28         east boldon
# 28  29           aberfeldy
# 29  30         penmaenmawr
# 30  31          billingham
# 31  32          milltimber
# 32  33               filey
# ...

# %%
df_county['county'] = df_county['county'].str.replace("'", '')
df_county['county'] = df_county['county'].str.replace('-','')
df_county['county'] = df_county['county'].str.replace('.','')

# %%
df_county = df_county.reset_index(drop=True)

# %%
df_county.head(80)
# Out:
#     id                     county
# 0    1              aberdeenshire
# 1    2           shetland islands
# 2    3                     antrim
# 3    4            south yorkshire
# 4    5                lanarkshire
# 5    6                     dorset
# 6    7                    suffolk
# 7    8           north humberside
# 8    9            kincardineshire
# 9   10                       down
# 10  11                 banffshire
# 11  12             dunbartonshire
# 12  13           south humberside
# 13  14            gloucestershire
# 14  15              hertfordshire
# 15  16                  hampshire
# 16  17            south glamorgan
# 17  18                londonderry
# 18  19               lincolnshire
# 19  20              mid glamorgan
# 20  21                     armagh
# 21  22                     tyrone
# 22  23               bedfordshire
# 23  24            nottinghamshire
# 24  25                  fermanagh
# 25  26                   cheshire
# ...

# %%
df_region['region'] = df_region['region'].str.replace("'", '')
df_region['region'] = df_region['region'].str.replace('-','')
df_region['region'] = df_region['region'].str.replace('.','')
df_region['region'] = df_region['region'].str.replace(',','')

# %%
df_region = df_region.reset_index(drop=True)

# %%
df_region.head(80)
# Out:
#     id                    region
# 0    1                south east
# 1    2                south west
# 2    3                    london
# 3    4           east of england
# 4    5             east midlands
# 5    6             west midlands
# 6    7  yorkshire and the humber
# 7    8                     north
# 8    9                  scotland
# 9   10                     wales
# 10  11          northern ireland
# 11  12           channel islands
# 12  19                    sussex

# %%
df_locality['locality'] = df_locality['locality'].str.replace(' ','')
df_city['city'] = df_city['city'].str.replace(' ','')
df_county['county'] = df_county['county'].str.replace(' ','')
df_region['region'] = df_region['region'].str.replace(' ','')

# %%
df_locnew.shape
# Out:
# (5521, 3)

# %%
df_locnew['location'] = df_locnew['location'].str.replace('-','')

# %%
df_locnew.head()
# Out:
#              type             location  Clicks
# 0  adult-services            abbeywood      40
# 1  adult-services        abbotslangley       4
# 2  adult-services             aberdeen     544
# 3  adult-services        aberdeenshire     171
# 4  adult-services  abingtonnorthampton       0

# %%
df_locnew = pd.merge(df_locnew, df_locality[['locality']], how='left', left_on='location', right_on='locality')

# %%
df_locnew.head()
# Out:
#              type             location  Clicks   locality
# 0  adult-services            abbeywood      40  abbeywood
# 1  adult-services        abbotslangley       4        NaN
# 2  adult-services             aberdeen     544        NaN
# 3  adult-services        aberdeenshire     171        NaN
# 4  adult-services  abingtonnorthampton       0        NaN

# %%
df_locnew.shape
# Out:
# (6249, 4)

# %%
df_locnew[df_locnew.duplicated()].count()
# Out:
# type        728
# location    728
# Clicks      728
# locality    728
# dtype: int64

# %%
df_locnew['category'] = df_locnew['locality'].apply(lambda x: 'locality' if pd.notna(x) else None)

# %%
df_locnew.head()
# Out:
#              type             location  Clicks   locality  category
# 0  adult-services            abbeywood      40  abbeywood  locality
# 1  adult-services        abbotslangley       4        NaN      None
# 2  adult-services             aberdeen     544        NaN      None
# 3  adult-services        aberdeenshire     171        NaN      None
# 4  adult-services  abingtonnorthampton       0        NaN      None

# %%
df_locnew = pd.merge(df_locnew, df_city[['city']], how='left', left_on='location', right_on='city')
df_locnew['category'] = df_locnew.apply(lambda row: 'city' if pd.notna(row['city']) else row['category'], axis=1)

# %%
df_locnew = pd.merge(df_locnew, df_county[['county']], how='left', left_on='location', right_on='county')
df_locnew['category'] = df_locnew.apply(lambda row: 'county' if pd.notna(row['county']) else row['category'], axis=1)

# %%
# Step 4: Merge df_locnew with df_region
df_locnew = pd.merge(df_locnew, df_region[['region']], how='left', left_on='location', right_on='region')
df_locnew['category'] = df_locnew.apply(lambda row: 'region' if pd.notna(row['region']) else row['category'], axis=1)

# Step 5: Drop the extra columns from the merges
df_locnew = df_locnew.drop(columns=['locality', 'city', 'county', 'region'])

# %%
df_locnew.head(80)
# Out:
#               type              location  Clicks  category
# 0   adult-services             abbeywood      40  locality
# 1   adult-services         abbotslangley       4      city
# 2   adult-services              aberdeen     544      city
# 3   adult-services         aberdeenshire     171    county
# 4   adult-services   abingtonnorthampton       0      None
# 5   adult-services            accrington       4      city
# 6   adult-services   acklammiddlesbrough       1      None
# 7   adult-services                 acton      77  locality
# 8   adult-services                 acton      77  locality
# 9   adult-services                 acton      77  locality
# 10  adult-services                 acton      77  locality
# 11  adult-services                 acton      77  locality
# 12  adult-services     actonhillstafford       0      None
# 13  adult-services             addington       0  locality
# 14  adult-services             addington       0  locality
# ...

# %%
df_locnew.isna().sum()
# Out:
# type           0
# location       0
# Clicks         0
# category    2849
# dtype: int64

# %%
df_locnew.shape
# Out:
# (6267, 4)

# %%
df_locnew.drop_duplicates(keep='first', inplace=True)

# %%
df_locnew = df_locnew[df_locnew['Clicks'] != 0]

# %%
df_locnew[df_locnew['category'].isnull()].reset_index(drop=True)
# Out:
#                type               location  Clicks category
# 0    adult-services    acklammiddlesbrough       1     None
# 1    adult-services      aigburthliverpool       1     None
# 2    adult-services       aintreeliverpool       5     None
# 3    adult-services        aldridgewalsall       2     None
# 4    adult-services    alsagerstokeontrent      13     None
# 5    adult-services     alumrockbirmingham       1     None
# 6    adult-services   alvechurchbirmingham       1     None
# 7    adult-services       anfieldliverpool      12     None
# 8    adult-services       annanwatermoffat       2     None
# 9    adult-services            armleyleeds       1     None
# 10   adult-services       arnoldnottingham      30     None
# 11   adult-services       arnosvalebristol       1     None
# 12   adult-services          ashcanterbury       1     None
# 13   adult-services       ashvalealdershot       4     None
# 14   adult-services         ashfieldromsey       1     None
# ...

# %%
df_locnew.loc[df_locnew.location == 'bradleystokebristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'cheshuntwalthamcross', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'clysthonitonexeter', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'colnbrookslough', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'coshamportsmouth', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'countyantrim', 'category'] = "county"
df_locnew.loc[df_locnew.location == 'countyfermanagh', 'category'] = "county"
df_locnew.loc[df_locnew.location == 'fishpondsbristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'frimleycamberley', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'greaterlondonlondon', 'category'] = "county"
df_locnew.loc[df_locnew.location == 'heathrowhounslow', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'kentashford', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'kentgillingham', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'kingswoodbristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'loginwhitland', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'longeatonnottingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'rainhamgillingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'selseychichester', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'stanwellstaines', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'stroodrochester', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'surreyashford', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'tottonsouthampton', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'uk', 'category'] = "uk"
df_locnew.loc[df_locnew.location == 'westthurrockgrays', 'category'] = "locality"

df_locnew.loc[df_locnew.location == 'ashingtonwimborne', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'astonbirmingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'elycardiff', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'erdingtonbirmingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'greatbarrbirmingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'gwentnewport', 'category'] = "city"
df_locnew.loc[df_locnew.location == 'hengrovebristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'kendleshirebristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'kintoreinverurie', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'knowlebristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'northfieldbirmingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'orpingtonkent', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'orrellparkliverpool', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'padihamburnley', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'portsladebrighton', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'shirleysolihull', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'smallheathbirmingham', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'thornburybradford', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'tilehurstreading', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'westderbyliverpool', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'westhillbristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'westfieldhastings', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'woottonabingdon', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'yatebristol', 'category'] = "locality"
df_locnew.loc[df_locnew.location == 'yattonbristol', 'category'] = "locality"

# %%
df_locnew['category'].value_counts()
# Out:
# category
# city        1013
# locality     417
# county       150
# region        17
# uk             6
# Name: count, dtype: int64

# %%
df_locnew = df_locnew[~df_locnew['category'].isna()]

# %%
df_locnew.to_clipboard(excel=True)

# %%
pd.pivot_table(df_locnew, index=['category'], values='Clicks', aggfunc=np.sum)
# Out:
#           Clicks
# category
# city      142519
# county     16520
# locality   12350
# region       526
# uk          4773

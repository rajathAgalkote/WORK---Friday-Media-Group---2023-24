# %% [markdown]
# # Collection research - Search categories

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

# importing decomposition modules
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import LatentDirichletAllocation

# importing Natural Language Toolkit and other NLP modules
import nltk
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob, Word
from nltk.corpus import stopwords
import re

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Firstview

# %%
df = pd.read_csv('/Users/rajathadri_as/Documents/FAD - searchTerms.csv')

# %%
pd.set_option('display.max_rows',None)

# %%
df.head()
# Out:
#   Search term  Total users
# 0     Massage        14814
# 1     massage         4554
# 2      Escort         3290
# 3     Escorts         2920
# 4         Sex         1874

# %%
df1 = df.copy()

# %%
df = df.drop('Total users', axis =1)

# %%
df.head()
# Out:
#   Search term
# 0     Massage
# 1     massage
# 2      Escort
# 3     Escorts
# 4         Sex

# %%
df.shape
# Out:
# (87733, 1)

# %% [markdown]
# ## Search Terms manipulation

# %%
list(df['Search term'])
# Out:
# ['Massage',
#  'massage',
#  'Escort',
#  'Escorts',
#  'Sex',
#  'Adult',
#  'Brighton',
#  'Adult massage',
#  'Kittens',
#  'Mature',
#  'Massage ',
#  'Eastbourne',
#  'Trans',
#  'Crawley',
#  'Hastings',
#  'Kent',
#  'London',
#  'Erotic massage',
#  'Hove',
#  'Canterbury',
#  'escort',
#  'Worthing',
#  'Kitten',
#  'Incall',
#  'Maidstone',
#  'Sofa',
#  'Adult services',
#  'Bbw',
#  'escorts',
#  'Asian',
#  'adult',
#  'Thai',
#  'Southampton',
#  'Free',
#  'Puppies',
#  'Milf',
#  'Escorts ',
#  'Dogs',
#  'Portsmouth',
#  'Gay',
#  'adult massage',
#  'Brighton ',
#  'Ts',
#  'Indian',
#  'Double bed',
#  'Croydon',
#  'Bristol',
#  'Eastbourne ',
#  'sex',
#  'Women',
#  'Chichester',
#  'Independent',
#  'Jumble sale',
#  'Shemale',
#  'Puppy',
#  'Dartford',
#  'Liverpool',
#  'Aldershot',
#  'Rochester',
#  'Cars',
#  'Chatham',
#  'Jobs',
#  'Anal',
#  'Margate',
#  'Male massage',
#  'Tv',
#  'Mass',
#  'Bed',
#  'Black',
#  'Escort ',
#  'Gravesend',
#  'Redhill',
#  'Tantric',
#  'Bareback',
#  'Caravan',
#  'adult services',
#  'Folkestone',
#  'Ashford',
#  'Es',
#  'Sensual massage',
#  'Surrey',
#  'Cats',
#  'Dog',
#  'Tantric massage',
#  'Van',
#  'Cleaner',
#  'Hastings ',
#  'Tunbridge wells',
#  'Male',
#  'Ebony',
#  'Esc',
#  'Thai massage',
#  'erotic massage',
#  'Ladyboy',
#  'M',
#  'Guildford',
#  'mature',
#  'Bike',
#  'Dating',
#  'Ramsgate',
#  'Corner sofa',
#  'Massa',
#  'jumble sale',
#  'Sofa bed',
#  'Bexhill',
#  'Fridge freezer',
#  'Outcall',
#  'Single bed',
#  'Cat',
#  'Car',
#  'Littlehampton',
#  'Dover',
#  'Essex',
#  'brighton',
#  'kittens',
#  'Farnborough',
#  'Fish tank',
#  'Canterbury ',
#  'Girls',
#  'Adult ',
#  'Dining table',
#  'Woman',
#  'Birds',
#  'Desk',
#  'free',
#  'Gillingham',
#  'Wardrobe',
#  'Fridge',
#  'Manchester',
#  'Adult massage ',
#  'sofa',
#  'Mobility scooter',
#  'Busty',
#  'Ma',
#  'Swindon',
#  'kitten',
#  'thai',
#  'Woking',
#  'In call',
#  'Shed',
#  'jobs',
#  'Hampshire',
#  'Washing machine',
#  'Birmingham',
#  'Wanted',
#  'Couple',
#  'Freezer',
#  'Granny',
#  'Mistress',
#  'Maidstone ',
#  'Feet',
#  'Table',
#  'auto sleeper transit',
#  'autosleeper transit',
#  'duetto',
#  'cars',
#  'incall',
#  'Bournemouth',
#  'Basingstoke',
#  'Budgies',
#  'Esco',
#  'Massage\xa0',
#  'Rent',
#  'Horsham',
#  'Sittingbourne',
#  'Vans',
#  'eastbourne',
#  'asian',
#  'Slough',
#  'Free stuff',
#  'Jumble sales',
#  'london',
#  'Bracknell',
#  'Free sex',
#  'In',
#  'Reading',
#  'Leeds',
#  'Female',
#  'crawley',
#  'Erotic',
#  'Room to rent',
#  'Nuru',
#  'English',
#  'Epsom',
#  'Kittens ',
#  'Sussex',
#  'Fareham',
#  'Massages',
#  'Blowjob',
#  'Bognor',
#  'Female escort',
#  'Rabbit',
#  'Chest of drawers',
#  'bike',
#  'hastings',
#  'A',
#  'Bunk beds',
#  'Logs',
#  'Phone sex',
#  'Ford fiesta',
#  'Jumble',
#  'Northampton',
#  'Tumble dryer',
#  'Escort services',
#  'dogs',
#  'Crawley ',
#  'Garage',
#  'Gay massage',
#  'Men',
#  'Private: Single Mum Looking For No Commitment Sex',
#  'Sofas',
#  'trans',
#  'E',
#  'Girl',
#  'Personal',
#  'Adult escort',
#  'Duo',
#  'Golf clubs',
#  'Guitar',
#  'Property to rent',
#  'Bath',
#  'Bromley',
#  'Mountain bike',
#  'Female escorts',
#  'Wheelchair',
#  'Chihuahua',
#  'Personal services',
#  'Automatic',
#  'Dining chairs',
#  'Table and chairs',
#  'tv',
#  'Adult services ',
#  'British',
#  'Sutton',
#  'Baby',
#  'Horses',
#  'car',
#  'Automatic cars',
#  'B',
#  'Beds',
#  'Camberley',
#  'Property',
#  'Worthing ',
#  'wanted',
#  'Garden furniture',
#  'Horse',
#  'MASSAGE',
#  'Motorhome',
#  'Portsmouth ',
#  'Southampton ',
#  'Hamster',
#  'Electric cooker',
#  'Rabbits',
#  'Workshop',
#  'worthing',
#  'Adult escorts',
#  'Couples',
#  'Pakistani',
#  'Treadmill',
#  'Happy ending',
#  'cleaner',
#  'tantric massage',
#  'Automatic car',
#  'Campervan',
#  'Chinese',
#  'Flat',
#  'Swingers',
#  'Bookcase',
#  'Cambridge',
#  'Parrot',
#  'Weights',
#  'double bed',
#  'French bulldog',
#  'Sideboard',
#  'aldershot',
#  'bed',
#  'desk',
#  'dining table',
#  'Cooker',
#  'East sussex',
#  'Erotic massage ',
#  'London ',
#  'Peterborough',
#  'Prostitute',
#  'Ad',
#  'Aline',
#  'Bunk bed',
#  'Fiat 500',
#  'Polish',
#  'Ps5',
#  'indian',
#  'male massage',
#  'Budgie',
#  'Chinese massage',
#  'Coffee table',
#  'Electric bike',
#  'Tonbridge',
#  'Maidenhead',
#  'Mature ',
#  'van',
#  'Mature massage',
#  'Nuru massage',
#  'West sussex',
#  'iPhone',
#  'puppies',
#  'Dominatrix',
#  'Puppies ',
#  'Glasgow',
#  'TS',
#  'Bmw',
#  'Coventry',
#  'Independent escorts',
#  'Pets',
#  'massage ',
#  'sensual massage',
#  'Chair',
#  'Lego',
#  'Rabbit hutch',
#  'S',
#  'caravan',
#  'Boat',
#  'Cardiff',
#  'Garage to rent',
#  'Hove ',
#  'dating',
#  'gay',
#  'Bikes',
#  'Escort service',
#  'Gosport',
#  'Hook up',
#  'Oxford',
#  'bbw',
#  'jumble sales',
#  'tantric',
#  'Chest freezer',
#  'East Sussex',
#  'Iphone',
#  'Male escort',
#  'Free to collector',
#  'Golf',
#  'Horley',
#  'Personals',
#  'T',
#  'Trailer',
#  'Air rifle',
#  'Garden',
#  'Moped',
#  'Shoes',
#  'Women ',
#  'Camper van',
#  'Colchester',
#  'Tranny',
#  'Fishing',
#  'Ford',
#  'Mas',
#  'Massag',
#  'bareback',
#  'Adults',
#  'Dishwasher',
#  'Dog crate',
#  'Exercise bike',
#  'Small double bed',
#  'kent',
#  'shed',
#  'High Wycombe',
#  'Kingston',
#  'Luton',
#  'Tunbridge Wells',
#  'Xbox',
#  'wardrobe',
#  'Independent escort',
#  'Kent ',
#  'King size bed',
#  'Lawn mower',
#  'Oriental',
#  'Stair gate',
#  'table',
#  'Farnham',
#  'Full body massage',
#  'Havant',
#  'Pigeons',
#  'maidstone',
#  'rent',
#  ' massage',
#  '125cc',
#  'Greenhouse',
#  'Labrador',
#  'fridge',
#  'milf',
#  'puppy',
#  'Manure',
#  'Mini',
#  'Sevenoaks',
#  'chest of drawers',
#  'dog',
#  'garage',
#  'mobility scooter',
#  'ts',
#  'Adult service',
#  'Caravans',
#  'Cocker spaniel',
#  'Gloryhole',
#  'Smart tv',
#  'redhill',
#  'Aldershot ',
#  'Bognor regis',
#  'Cockapoo',
#  'Guinea pig',
#  'Handyman',
#  'Independent ',
#  'Tortoise',
#  'guitar',
#  'Fetish',
#  'House to rent',
#  'Japanese',
#  'West Sussex',
#  'ashford',
#  'free stuff',
#  'sofa bed',
#  '4x4',
#  'Asian massage',
#  'Body to body massage',
#  'Domination',
#  'Fish',
#  'Hailsham',
#  'Leicester',
#  'Part time',
#  'bexhill',
#  'canterbury',
#  '7 seater',
#  'Brazilian',
#  'Escourt',
#  'Gardener',
#  'Sewing machine',
#  'Stevenage',
#  'freezer',
#  'Basildon',
#  'Chickens',
#  'Hoover',
#  'Incalls',
#  'Oven',
#  'Staines',
#  'Storage',
#  'farnborough',
#  'mistress',
#  'thai massage',
#  'Armchair',
#  'Bicycle',
#  'Flat to rent',
#  'Furniture',
#  'Hookup',
#  'Room',
#  'Watford',
#  'cats',
#  'iphone',
#  'Adult contacts',
#  'C',
#  'Call girls',
#  'Camping',
#  'Garden shed',
#  'Kittens for sale',
#  'Mature escort',
#  'Adult Massage',
#  'Brentwood',
#  'Dressing table',
#  'Guinea pigs',
#  'Roof box',
#  'office chair',
#  'women',
#  'Audi',
#  'Chicken',
#  'Derby',
#  'East',
#  'Glory hole',
#  'Guildford ',
#  'L',
#  'Nsa',
#  'Strood',
#  'fridge freezer',
#  'ladyboy',
#  'single bed',
#  'Bed frame',
#  'Br',
#  'German shepherd',
#  'Ipswich',
#  'Liverpool ',
#  'Prostitutes',
#  'Pug',
#  'Rochester ',
#  'room to rent',
#  'washing machine',
#  'Adu',
#  'Bedford',
#  'Bognor Regis',
#  'Crossdresser',
#  'Escourts',
#  'Kettering',
#  'Lewes',
#  'Tent',
#  'Tools',
#  'Transexual',
#  'gay massage',
#  'Bi',
#  'Cleaning',
#  'Farnborough ',
#  'Flats to rent',
#  'Hounslow',
#  'Leather sofa',
#  'Massage adult',
#  'Southend',
#  'Transgender',
#  'Blonde',
#  'Border collie',
#  'Dachshund',
#  'Female escorts ',
#  'Office chair',
#  'Sheds',
#  'Threesome',
#  'Tunbridge',
#  'Volvo',
#  'personal',
#  'Big',
#  'Bird cage',
#  'Bricks',
#  'Bristol ',
#  'Curvy',
#  'Foot fetish',
#  'Ford focus',
#  'Kitchen',
#  'Man',
#  'Piano',
#  'Room for rent',
#  'Vivarium',
#  'portsmouth',
#  'Berkshire',
#  'Cim',
#  'Dogging',
#  'Dolls house',
#  'Drawers',
#  'Exeter',
#  'Free to collect',
#  'Kayak',
#  'Paving slabs',
#  'Sissy',
#  'Stripchat',
#  'anal',
#  'job',
#  'Brighton\xa0',
#  'Casual sex',
#  'Chairs',
#  'Maine coon',
#  'Mattress',
#  'Nottingham',
#  'P',
#  'Studio flat',
#  'Wood',
#  'Gloucester',
#  'H',
#  'Parrots',
#  'Party',
#  'Pony',
#  'Sexy',
#  'Trans escorts',
#  'W',
#  'jumble',
#  'nuru',
#  'personal services',
#  'shemale',
#  'workshop',
#  'Call girl',
#  'Dorset',
#  'Fleet',
#  'Gas cooker',
#  'Hay',
#  'Job',
#  'Latina',
#  'Message',
#  'Polegate',
#  'Pomeranian',
#  'Scooter',
#  'Secure single garage with store room',
#  'Spanking',
#  'Ts escort',
#  'bicycle',
#  'camberley',
#  'woman',
#  'Chelmsford',
#  'Escor',
#  'Foot',
#  'Gay escorts',
#  'Gravesend ',
#  'Honda',
#  'I',
#  'Indian ',
#  'Laptop',
#  'Newcastle',
#  'Nintendo switch',
#  'Romford',
#  'Strap on',
#  'Suitcase',
#  'To rent',
#  'Tra',
#  'Trans escort',
#  'Whitstable',
#  'Winchester',
#  'Yorkshire terrier',
#  'cat',
#  'garage to rent',
#  'Cement mixer',
#  'Croydon ',
#  'Dartford ',
#  'Enfield',
#  'Escort massage',
#  'F',
#  'Gatwick',
#  'Harrow',
#  'Jack Russell',
#  'Mercedes',
#  'Nintendo',
#  'Pool table',
#  'TV',
#  'Toys',
#  'Tran',
#  'bookcase',
#  'folkestone',
#  'hove',
#  'southampton',
#  '125',
#  'Body massage',
#  'Double bed frame',
#  'Ferret',
#  'Ferrets',
#  'G',
#  'Gazebo',
#  'Ilford',
#  'Inde',
#  'Jumble sale ',
#  'Merseyside',
#  'Owo',
#  'Phone',
#  'Ragdoll',
#  'Rug',
#  'Sheffield',
#  'Waxing',
#  'adult escorts',
#  'budgies',
#  'campervan',
#  'electric bike',
#  'fish tank',
#  'ford fiesta',
#  'free to collector',
#  'vans',
#  'African grey',
#  'Bedside table',
#  'Bradford',
#  'Driver',
#  'Inca',
#  'Labourer',
#  'Masage',
#  'Norwich',
#  'Reigate',
#  'Rottweiler',
#  'Salisbury',
#  'Se',
#  'Sex ',
#  'domination',
#  'independent',
#  'lawn mower',
#  '50cc',
#  'Adult work',
#  'Bdsm',
#  'Carpet',
#  'Cavapoo',
#  'Dorking',
#  'Double mattress',
#  'Kallax',
#  'Metal detector',
#  'Ps4',
#  'Sexual massage',
#  'Wales',
#  'York',
#  'bristol',
#  'dominatrix',
#  'escort services',
#  'logs',
#  'massage services',
#  'motorhome',
#  'Camper',
#  'Corsa',
#  'Golden retriever',
#  'Haywards heath',
#  'Ikea',
#  'Livery',
#  'New',
#  'Sex massage',
#  'birds',
#  'gardener',
#  'speakers',
#  'Adult fun',
#  'Andover',
#  'Dining table and chairs',
#  'Double bed ',
#  'Fiesta',
#  'Flats',
#  'Fridge freezer ',
#  'Garden table',
#  'Happy ending massage',
#  'Heathrow',
#  'Honda stepwgn',
#  'Kitten ',
#  'Milfs',
#  'Staffordshire bull terrier',
#  'Uxbridge',
#  'Vw polo',
#  'Wiltshire',
#  'female',
#  'trailer',
#  'Audi a3',
#  'Carer',
#  'Cheshire',
#  'Chester',
#  'Chicken coop',
#  'Electric scooter',
#  'Gay escort',
#  'Hull',
#  'Ladder',
#  'Lawnmower',
#  'Male escorts',
#  'Man with van',
#  'Massage services',
#  'Nissan',
#  'Pegging',
#  'Rooms to rent',
#  'Studio',
#  'Teen',
#  'Touring caravan',
#  'Toyota',
#  'Transit',
#  'Vauxhall corsa',
#  'Wardrobe ',
#  'chair',
#  'female escorts',
#  'Adult sex',
#  'Big tits',
#  'Blow job',
#  'Body to body',
#  'Chat',
#  'Edinburgh',
#  'Ind',
#  'Lancashire',
#  'Mature escorts',
#  'Mirror',
#  'Part time jobs',
#  'Prostate',
#  'Wardrobes',
#  'Waterlooville',
#  'Wembley',
#  'Woman ',
#  'horsham',
#  'storage',
#  'tumble dryer',
#  'Boats',
#  'Burgess hill',
#  'Devon',
#  'Eastbourne\xa0',
#  'Honda jazz',
#  'Lady',
#  'Recliner chair',
#  'Sensual',
#  'Sex workers',
#  'Single beds',
#  'Strimmer',
#  'Thai massage ',
#  'Transsexual',
#  'Xl bully',
#  'coventry',
#  'ebony',
#  'garden furniture',
#  'treadmill',
#  '18',
#  'Adul',
#  'Bird',
#  'Casual',
#  'Escort girls',
#  'Feltham',
#  'Kids bike',
#  'Lesbian',
#  'Lo',
#  'Meet',
#  'Old',
#  'Plymouth',
#  'Washing machine ',
#  'cheap  sex',
#  'chinese massage',
#  'cooker',
#  'furniture',
#  'girls',
#  'golf clubs',
#  'male',
#  'microwave',
#  'property to rent',
#  'Bulldog',
#  'Ca',
#  'Date',
#  'Garage for rent',
#  'Gay men',
#  'Hayes',
#  'Larissa',
#  'Loan',
#  'Man with a van',
#  'Microwave',
#  'Nissan juke',
#  'Plumber',
#  'Shoreham',
#  'Slut',
#  'Sofabed',
#  'Strapon',
#  'Stroller',
#  'Swanley',
#  'Television',
#  'Tr',
#  'carer',
#  'margate',
#  'rabbit',
#  'wheelchair',
#  'Bedroom furniture',
#  'Big ass',
#  'Car meet',
#  'Dating ',
#  'Doors',
#  'English bulldog',
#  'Female escort ',
#  'Fun',
#  'Gfe',
#  'Houses to rent',
#  'K',
#  'Kitchen units',
#  'Petite',
#  'Pigeon',
#  'Poole',
#  'Sensual massage ',
#  'Speakers',
#  'Trans massage',
#  'Tv unit',
#  'automatic',
#  'corner sofa',
#  'flat to rent',
#  'horses',
#  'mature massage',
#  'sewing machine',
#  'surrey',
#  'weights',
#  'Bexley',
#  'Bj',
#  'Cleaners',
#  'Doncaster',
#  'Ford transit',
#  'Freebies',
#  'Fuck',
#  'Jack russell',
#  'Latin',
#  'Lawn bowls',
#  'Leatherhead',
#  'Massage escort',
#  'Massage parlour',
#  'Motorhomes',
#  'Naked',
#  'Out call',
#  'Trackhawk',
#  'Whippet',
#  'automatic cars',
#  'computer',
#  'erotic',
#  'fishing',
#  'greenhouse',
#  'mirror',
#  'moped',
#  'outcall',
#  'personals',
#  'property',
#  'rabbits',
#  'Ashford kent',
#  'Bearded dragon',
#  'Bmx',
#  'Brazil',
#  'Cane corso',
#  'Cars for sale',
#  'Cash in hand',
#  'Folding bike',
#  'Golf bag',
#  'Hertfordshire',
#  'Horsebox',
#  'House',
#  'Male massage ',
#  'Man and van',
#  'Mobility scooters',
#  'Out',
#  'Puppys',
#  'Record player',
#  'Removals',
#  'Snapchat',
#  'Tantric massage ',
#  'Toyota aygo',
#  'Young',
#  'bdsm',
#  'camper van',
#  'mature escort',
#  'monitor',
#  'vw polo',
#  '2 seater sofa',
#  'Adult service ',
#  'As',
#  'Ashford ',
#  'Asian ',
#  'Auto',
#  'Cam',
#  'Canary',
#  'Chesterfield',
#  'Clothes rail',
#  'East grinstead',
#  'Eastleigh',
#  'Femboy',
#  'Fiat',
#  'Fish tanks',
#  'Lingam',
#  'Motorcycle',
#  'Orpington',
#  'Porn',
#  'Prostitute ',
#  'Puppies for sale',
#  'Scotland',
#  'Settee',
#  'Women seeking men',
#  'Yorkshire',
#  'boat',
#  'chinese',
#  'classic cars',
#  'exercise bike',
#  'female escort',
#  'garden shed',
#  'handyman',
#  'hay',
#  'lego',
#  'nuru massage',
#  'paving slabs',
#  'polish',
#  'spanking',
#  'Adult dating',
#  'Bexhill on sea',
#  'Bruna',
#  'Can',
#  'Canaries',
#  'Cockatiel',
#  'Folkestone ',
#  'Hamster cage',
#  'Honda nsx',
#  'Hooker',
#  'Hutch',
#  'I call',
#  'Lisa',
#  'Lurcher',
#  'Panties',
#  'Personal ads',
#  'Prostitution',
#  'Range rover',
#  'Staffy',
#  'Swansea',
#  'Trans ',
#  'Tumble dryer ',
#  'Vans for sale',
#  'Video',
#  'Vw',
#  'chatham',
#  'coffee table',
#  'croydon',
#  'ford focus',
#  'massages',
#  'model',
#  'mower',
#  'piano',
#  'room',
#  'sussex',
#  '125cc motorbike',
#  'Alton',
#  'Blackpool',
#  'Bri',
#  'Broadstairs',
#  'Carpenter',
#  'Chihuahua ',
#  'Christmas tree',
#  'Coffee machine',
#  'D',
#  'Dogs for sale',
#  'Dyson',
#  'Gay dating',
#  'Harlow',
#  'Hedge trimmer',
#  'Honda civic',
#  'Ladders',
#  'Lady boy',
#  ...]

# %%
corpus_temp = []

text = list(df['Search term'])

for i in range(len(text)):
    r = re.sub('[^a-zA-Z]', ' ', str(text[i]))
    r = r.lower()
    r = r.split()
#     r = [word for word in r if word not in stopwords.words('english')]
#     r = [lemmatizer.lemmatize(word) for word in r]
    r = ' '.join(r)
    corpus_temp.append(r)

# %%
corpus_temp
# Out:
# ['massage',
#  'massage',
#  'escort',
#  'escorts',
#  'sex',
#  'adult',
#  'brighton',
#  'adult massage',
#  'kittens',
#  'mature',
#  'massage',
#  'eastbourne',
#  'trans',
#  'crawley',
#  'hastings',
#  'kent',
#  'london',
#  'erotic massage',
#  'hove',
#  'canterbury',
#  'escort',
#  'worthing',
#  'kitten',
#  'incall',
#  'maidstone',
#  'sofa',
#  'adult services',
#  'bbw',
#  'escorts',
#  'asian',
#  'adult',
#  'thai',
#  'southampton',
#  'free',
#  'puppies',
#  'milf',
#  'escorts',
#  'dogs',
#  'portsmouth',
#  'gay',
#  'adult massage',
#  'brighton',
#  'ts',
#  'indian',
#  'double bed',
#  'croydon',
#  'bristol',
#  'eastbourne',
#  'sex',
#  'women',
#  'chichester',
#  'independent',
#  'jumble sale',
#  'shemale',
#  'puppy',
#  'dartford',
#  'liverpool',
#  'aldershot',
#  'rochester',
#  'cars',
#  'chatham',
#  'jobs',
#  'anal',
#  'margate',
#  'male massage',
#  'tv',
#  'mass',
#  'bed',
#  'black',
#  'escort',
#  'gravesend',
#  'redhill',
#  'tantric',
#  'bareback',
#  'caravan',
#  'adult services',
#  'folkestone',
#  'ashford',
#  'es',
#  'sensual massage',
#  'surrey',
#  'cats',
#  'dog',
#  'tantric massage',
#  'van',
#  'cleaner',
#  'hastings',
#  'tunbridge wells',
#  'male',
#  'ebony',
#  'esc',
#  'thai massage',
#  'erotic massage',
#  'ladyboy',
#  'm',
#  'guildford',
#  'mature',
#  'bike',
#  'dating',
#  'ramsgate',
#  'corner sofa',
#  'massa',
#  'jumble sale',
#  'sofa bed',
#  'bexhill',
#  'fridge freezer',
#  'outcall',
#  'single bed',
#  'cat',
#  'car',
#  'littlehampton',
#  'dover',
#  'essex',
#  'brighton',
#  'kittens',
#  'farnborough',
#  'fish tank',
#  'canterbury',
#  'girls',
#  'adult',
#  'dining table',
#  'woman',
#  'birds',
#  'desk',
#  'free',
#  'gillingham',
#  'wardrobe',
#  'fridge',
#  'manchester',
#  'adult massage',
#  'sofa',
#  'mobility scooter',
#  'busty',
#  'ma',
#  'swindon',
#  'kitten',
#  'thai',
#  'woking',
#  'in call',
#  'shed',
#  'jobs',
#  'hampshire',
#  'washing machine',
#  'birmingham',
#  'wanted',
#  'couple',
#  'freezer',
#  'granny',
#  'mistress',
#  'maidstone',
#  'feet',
#  'table',
#  'auto sleeper transit',
#  'autosleeper transit',
#  'duetto',
#  'cars',
#  'incall',
#  'bournemouth',
#  'basingstoke',
#  'budgies',
#  'esco',
#  'massage',
#  'rent',
#  'horsham',
#  'sittingbourne',
#  'vans',
#  'eastbourne',
#  'asian',
#  'slough',
#  'free stuff',
#  'jumble sales',
#  'london',
#  'bracknell',
#  'free sex',
#  'in',
#  'reading',
#  'leeds',
#  'female',
#  'crawley',
#  'erotic',
#  'room to rent',
#  'nuru',
#  'english',
#  'epsom',
#  'kittens',
#  'sussex',
#  'fareham',
#  'massages',
#  'blowjob',
#  'bognor',
#  'female escort',
#  'rabbit',
#  'chest of drawers',
#  'bike',
#  'hastings',
#  'a',
#  'bunk beds',
#  'logs',
#  'phone sex',
#  'ford fiesta',
#  'jumble',
#  'northampton',
#  'tumble dryer',
#  'escort services',
#  'dogs',
#  'crawley',
#  'garage',
#  'gay massage',
#  'men',
#  'private single mum looking for no commitment sex',
#  'sofas',
#  'trans',
#  'e',
#  'girl',
#  'personal',
#  'adult escort',
#  'duo',
#  'golf clubs',
#  'guitar',
#  'property to rent',
#  'bath',
#  'bromley',
#  'mountain bike',
#  'female escorts',
#  'wheelchair',
#  'chihuahua',
#  'personal services',
#  'automatic',
#  'dining chairs',
#  'table and chairs',
#  'tv',
#  'adult services',
#  'british',
#  'sutton',
#  'baby',
#  'horses',
#  'car',
#  'automatic cars',
#  'b',
#  'beds',
#  'camberley',
#  'property',
#  'worthing',
#  'wanted',
#  'garden furniture',
#  'horse',
#  'massage',
#  'motorhome',
#  'portsmouth',
#  'southampton',
#  'hamster',
#  'electric cooker',
#  'rabbits',
#  'workshop',
#  'worthing',
#  'adult escorts',
#  'couples',
#  'pakistani',
#  'treadmill',
#  'happy ending',
#  'cleaner',
#  'tantric massage',
#  'automatic car',
#  'campervan',
#  'chinese',
#  'flat',
#  'swingers',
#  'bookcase',
#  'cambridge',
#  'parrot',
#  'weights',
#  'double bed',
#  'french bulldog',
#  'sideboard',
#  'aldershot',
#  'bed',
#  'desk',
#  'dining table',
#  'cooker',
#  'east sussex',
#  'erotic massage',
#  'london',
#  'peterborough',
#  'prostitute',
#  'ad',
#  'aline',
#  'bunk bed',
#  'fiat',
#  'polish',
#  'ps',
#  'indian',
#  'male massage',
#  'budgie',
#  'chinese massage',
#  'coffee table',
#  'electric bike',
#  'tonbridge',
#  'maidenhead',
#  'mature',
#  'van',
#  'mature massage',
#  'nuru massage',
#  'west sussex',
#  'iphone',
#  'puppies',
#  'dominatrix',
#  'puppies',
#  'glasgow',
#  'ts',
#  'bmw',
#  'coventry',
#  'independent escorts',
#  'pets',
#  'massage',
#  'sensual massage',
#  'chair',
#  'lego',
#  'rabbit hutch',
#  's',
#  'caravan',
#  'boat',
#  'cardiff',
#  'garage to rent',
#  'hove',
#  'dating',
#  'gay',
#  'bikes',
#  'escort service',
#  'gosport',
#  'hook up',
#  'oxford',
#  'bbw',
#  'jumble sales',
#  'tantric',
#  'chest freezer',
#  'east sussex',
#  'iphone',
#  'male escort',
#  'free to collector',
#  'golf',
#  'horley',
#  'personals',
#  't',
#  'trailer',
#  'air rifle',
#  'garden',
#  'moped',
#  'shoes',
#  'women',
#  'camper van',
#  'colchester',
#  'tranny',
#  'fishing',
#  'ford',
#  'mas',
#  'massag',
#  'bareback',
#  'adults',
#  'dishwasher',
#  'dog crate',
#  'exercise bike',
#  'small double bed',
#  'kent',
#  'shed',
#  'high wycombe',
#  'kingston',
#  'luton',
#  'tunbridge wells',
#  'xbox',
#  'wardrobe',
#  'independent escort',
#  'kent',
#  'king size bed',
#  'lawn mower',
#  'oriental',
#  'stair gate',
#  'table',
#  'farnham',
#  'full body massage',
#  'havant',
#  'pigeons',
#  'maidstone',
#  'rent',
#  'massage',
#  'cc',
#  'greenhouse',
#  'labrador',
#  'fridge',
#  'milf',
#  'puppy',
#  'manure',
#  'mini',
#  'sevenoaks',
#  'chest of drawers',
#  'dog',
#  'garage',
#  'mobility scooter',
#  'ts',
#  'adult service',
#  'caravans',
#  'cocker spaniel',
#  'gloryhole',
#  'smart tv',
#  'redhill',
#  'aldershot',
#  'bognor regis',
#  'cockapoo',
#  'guinea pig',
#  'handyman',
#  'independent',
#  'tortoise',
#  'guitar',
#  'fetish',
#  'house to rent',
#  'japanese',
#  'west sussex',
#  'ashford',
#  'free stuff',
#  'sofa bed',
#  'x',
#  'asian massage',
#  'body to body massage',
#  'domination',
#  'fish',
#  'hailsham',
#  'leicester',
#  'part time',
#  'bexhill',
#  'canterbury',
#  'seater',
#  'brazilian',
#  'escourt',
#  'gardener',
#  'sewing machine',
#  'stevenage',
#  'freezer',
#  'basildon',
#  'chickens',
#  'hoover',
#  'incalls',
#  'oven',
#  'staines',
#  'storage',
#  'farnborough',
#  'mistress',
#  'thai massage',
#  'armchair',
#  'bicycle',
#  'flat to rent',
#  'furniture',
#  'hookup',
#  'room',
#  'watford',
#  'cats',
#  'iphone',
#  'adult contacts',
#  'c',
#  'call girls',
#  'camping',
#  'garden shed',
#  'kittens for sale',
#  'mature escort',
#  'adult massage',
#  'brentwood',
#  'dressing table',
#  'guinea pigs',
#  'roof box',
#  'office chair',
#  'women',
#  'audi',
#  'chicken',
#  'derby',
#  'east',
#  'glory hole',
#  'guildford',
#  'l',
#  'nsa',
#  'strood',
#  'fridge freezer',
#  'ladyboy',
#  'single bed',
#  'bed frame',
#  'br',
#  'german shepherd',
#  'ipswich',
#  'liverpool',
#  'prostitutes',
#  'pug',
#  'rochester',
#  'room to rent',
#  'washing machine',
#  'adu',
#  'bedford',
#  'bognor regis',
#  'crossdresser',
#  'escourts',
#  'kettering',
#  'lewes',
#  'tent',
#  'tools',
#  'transexual',
#  'gay massage',
#  'bi',
#  'cleaning',
#  'farnborough',
#  'flats to rent',
#  'hounslow',
#  'leather sofa',
#  'massage adult',
#  'southend',
#  'transgender',
#  'blonde',
#  'border collie',
#  'dachshund',
#  'female escorts',
#  'office chair',
#  'sheds',
#  'threesome',
#  'tunbridge',
#  'volvo',
#  'personal',
#  'big',
#  'bird cage',
#  'bricks',
#  'bristol',
#  'curvy',
#  'foot fetish',
#  'ford focus',
#  'kitchen',
#  'man',
#  'piano',
#  'room for rent',
#  'vivarium',
#  'portsmouth',
#  'berkshire',
#  'cim',
#  'dogging',
#  'dolls house',
#  'drawers',
#  'exeter',
#  'free to collect',
#  'kayak',
#  'paving slabs',
#  'sissy',
#  'stripchat',
#  'anal',
#  'job',
#  'brighton',
#  'casual sex',
#  'chairs',
#  'maine coon',
#  'mattress',
#  'nottingham',
#  'p',
#  'studio flat',
#  'wood',
#  'gloucester',
#  'h',
#  'parrots',
#  'party',
#  'pony',
#  'sexy',
#  'trans escorts',
#  'w',
#  'jumble',
#  'nuru',
#  'personal services',
#  'shemale',
#  'workshop',
#  'call girl',
#  'dorset',
#  'fleet',
#  'gas cooker',
#  'hay',
#  'job',
#  'latina',
#  'message',
#  'polegate',
#  'pomeranian',
#  'scooter',
#  'secure single garage with store room',
#  'spanking',
#  'ts escort',
#  'bicycle',
#  'camberley',
#  'woman',
#  'chelmsford',
#  'escor',
#  'foot',
#  'gay escorts',
#  'gravesend',
#  'honda',
#  'i',
#  'indian',
#  'laptop',
#  'newcastle',
#  'nintendo switch',
#  'romford',
#  'strap on',
#  'suitcase',
#  'to rent',
#  'tra',
#  'trans escort',
#  'whitstable',
#  'winchester',
#  'yorkshire terrier',
#  'cat',
#  'garage to rent',
#  'cement mixer',
#  'croydon',
#  'dartford',
#  'enfield',
#  'escort massage',
#  'f',
#  'gatwick',
#  'harrow',
#  'jack russell',
#  'mercedes',
#  'nintendo',
#  'pool table',
#  'tv',
#  'toys',
#  'tran',
#  'bookcase',
#  'folkestone',
#  'hove',
#  'southampton',
#  '',
#  'body massage',
#  'double bed frame',
#  'ferret',
#  'ferrets',
#  'g',
#  'gazebo',
#  'ilford',
#  'inde',
#  'jumble sale',
#  'merseyside',
#  'owo',
#  'phone',
#  'ragdoll',
#  'rug',
#  'sheffield',
#  'waxing',
#  'adult escorts',
#  'budgies',
#  'campervan',
#  'electric bike',
#  'fish tank',
#  'ford fiesta',
#  'free to collector',
#  'vans',
#  'african grey',
#  'bedside table',
#  'bradford',
#  'driver',
#  'inca',
#  'labourer',
#  'masage',
#  'norwich',
#  'reigate',
#  'rottweiler',
#  'salisbury',
#  'se',
#  'sex',
#  'domination',
#  'independent',
#  'lawn mower',
#  'cc',
#  'adult work',
#  'bdsm',
#  'carpet',
#  'cavapoo',
#  'dorking',
#  'double mattress',
#  'kallax',
#  'metal detector',
#  'ps',
#  'sexual massage',
#  'wales',
#  'york',
#  'bristol',
#  'dominatrix',
#  'escort services',
#  'logs',
#  'massage services',
#  'motorhome',
#  'camper',
#  'corsa',
#  'golden retriever',
#  'haywards heath',
#  'ikea',
#  'livery',
#  'new',
#  'sex massage',
#  'birds',
#  'gardener',
#  'speakers',
#  'adult fun',
#  'andover',
#  'dining table and chairs',
#  'double bed',
#  'fiesta',
#  'flats',
#  'fridge freezer',
#  'garden table',
#  'happy ending massage',
#  'heathrow',
#  'honda stepwgn',
#  'kitten',
#  'milfs',
#  'staffordshire bull terrier',
#  'uxbridge',
#  'vw polo',
#  'wiltshire',
#  'female',
#  'trailer',
#  'audi a',
#  'carer',
#  'cheshire',
#  'chester',
#  'chicken coop',
#  'electric scooter',
#  'gay escort',
#  'hull',
#  'ladder',
#  'lawnmower',
#  'male escorts',
#  'man with van',
#  'massage services',
#  'nissan',
#  'pegging',
#  'rooms to rent',
#  'studio',
#  'teen',
#  'touring caravan',
#  'toyota',
#  'transit',
#  'vauxhall corsa',
#  'wardrobe',
#  'chair',
#  'female escorts',
#  'adult sex',
#  'big tits',
#  'blow job',
#  'body to body',
#  'chat',
#  'edinburgh',
#  'ind',
#  'lancashire',
#  'mature escorts',
#  'mirror',
#  'part time jobs',
#  'prostate',
#  'wardrobes',
#  'waterlooville',
#  'wembley',
#  'woman',
#  'horsham',
#  'storage',
#  'tumble dryer',
#  'boats',
#  'burgess hill',
#  'devon',
#  'eastbourne',
#  'honda jazz',
#  'lady',
#  'recliner chair',
#  'sensual',
#  'sex workers',
#  'single beds',
#  'strimmer',
#  'thai massage',
#  'transsexual',
#  'xl bully',
#  'coventry',
#  'ebony',
#  'garden furniture',
#  'treadmill',
#  '',
#  'adul',
#  'bird',
#  'casual',
#  'escort girls',
#  'feltham',
#  'kids bike',
#  'lesbian',
#  'lo',
#  'meet',
#  'old',
#  'plymouth',
#  'washing machine',
#  'cheap sex',
#  'chinese massage',
#  'cooker',
#  'furniture',
#  'girls',
#  'golf clubs',
#  'male',
#  'microwave',
#  'property to rent',
#  'bulldog',
#  'ca',
#  'date',
#  'garage for rent',
#  'gay men',
#  'hayes',
#  'larissa',
#  'loan',
#  'man with a van',
#  'microwave',
#  'nissan juke',
#  'plumber',
#  'shoreham',
#  'slut',
#  'sofabed',
#  'strapon',
#  'stroller',
#  'swanley',
#  'television',
#  'tr',
#  'carer',
#  'margate',
#  'rabbit',
#  'wheelchair',
#  'bedroom furniture',
#  'big ass',
#  'car meet',
#  'dating',
#  'doors',
#  'english bulldog',
#  'female escort',
#  'fun',
#  'gfe',
#  'houses to rent',
#  'k',
#  'kitchen units',
#  'petite',
#  'pigeon',
#  'poole',
#  'sensual massage',
#  'speakers',
#  'trans massage',
#  'tv unit',
#  'automatic',
#  'corner sofa',
#  'flat to rent',
#  'horses',
#  'mature massage',
#  'sewing machine',
#  'surrey',
#  'weights',
#  'bexley',
#  'bj',
#  'cleaners',
#  'doncaster',
#  'ford transit',
#  'freebies',
#  'fuck',
#  'jack russell',
#  'latin',
#  'lawn bowls',
#  'leatherhead',
#  'massage escort',
#  'massage parlour',
#  'motorhomes',
#  'naked',
#  'out call',
#  'trackhawk',
#  'whippet',
#  'automatic cars',
#  'computer',
#  'erotic',
#  'fishing',
#  'greenhouse',
#  'mirror',
#  'moped',
#  'outcall',
#  'personals',
#  'property',
#  'rabbits',
#  'ashford kent',
#  'bearded dragon',
#  'bmx',
#  'brazil',
#  'cane corso',
#  'cars for sale',
#  'cash in hand',
#  'folding bike',
#  'golf bag',
#  'hertfordshire',
#  'horsebox',
#  'house',
#  'male massage',
#  'man and van',
#  'mobility scooters',
#  'out',
#  'puppys',
#  'record player',
#  'removals',
#  'snapchat',
#  'tantric massage',
#  'toyota aygo',
#  'young',
#  'bdsm',
#  'camper van',
#  'mature escort',
#  'monitor',
#  'vw polo',
#  'seater sofa',
#  'adult service',
#  'as',
#  'ashford',
#  'asian',
#  'auto',
#  'cam',
#  'canary',
#  'chesterfield',
#  'clothes rail',
#  'east grinstead',
#  'eastleigh',
#  'femboy',
#  'fiat',
#  'fish tanks',
#  'lingam',
#  'motorcycle',
#  'orpington',
#  'porn',
#  'prostitute',
#  'puppies for sale',
#  'scotland',
#  'settee',
#  'women seeking men',
#  'yorkshire',
#  'boat',
#  'chinese',
#  'classic cars',
#  'exercise bike',
#  'female escort',
#  'garden shed',
#  'handyman',
#  'hay',
#  'lego',
#  'nuru massage',
#  'paving slabs',
#  'polish',
#  'spanking',
#  'adult dating',
#  'bexhill on sea',
#  'bruna',
#  'can',
#  'canaries',
#  'cockatiel',
#  'folkestone',
#  'hamster cage',
#  'honda nsx',
#  'hooker',
#  'hutch',
#  'i call',
#  'lisa',
#  'lurcher',
#  'panties',
#  'personal ads',
#  'prostitution',
#  'range rover',
#  'staffy',
#  'swansea',
#  'trans',
#  'tumble dryer',
#  'vans for sale',
#  'video',
#  'vw',
#  'chatham',
#  'coffee table',
#  'croydon',
#  'ford focus',
#  'massages',
#  'model',
#  'mower',
#  'piano',
#  'room',
#  'sussex',
#  'cc motorbike',
#  'alton',
#  'blackpool',
#  'bri',
#  'broadstairs',
#  'carpenter',
#  'chihuahua',
#  'christmas tree',
#  'coffee machine',
#  'd',
#  'dogs for sale',
#  'dyson',
#  'gay dating',
#  'harlow',
#  'hedge trimmer',
#  'honda civic',
#  'ladders',
#  'lady boy',
#  ...]

# %%
len(corpus_temp)
# Out:
# 87733

# %% [markdown]
# ### Dropping Duplicates

# %%
clean_list = list(set(corpus_temp))

# %%
clean_list
# Out:
# ['',
#  'single bed base with drawers',
#  'cast iron post',
#  'momen retorts',
#  'bengali girl',
#  'gravel stones shingle',
#  'van vault tipper',
#  'rent gay boys',
#  'iron gates',
#  'bedford properties to rent',
#  'purebred yorkshire terrier pups for sale',
#  'exercise bike cross trainer',
#  'auto car',
#  'gi',
#  'motor car',
#  'stair lifts',
#  'boulders for sale',
#  'lkj flooring services ltd',
#  'philips light bulbs',
#  'callaway',
#  'cheeky',
#  'incqll',
#  'pc keyboard',
#  'adult bicycles',
#  'zimmer frames',
#  'loft',
#  'knee high boots',
#  'kodi boxes',
#  'your local oriental spice chinese escort massage service plumstead se',
#  'free blowjob',
#  'tap push on hose',
#  'black francolin',
#  'driver warehou',
#  'ailia',
#  'honda cc',
#  'yacht craddle',
#  'prudence',
#  'skoda rapid',
#  'exult',
#  'children table and chairs',
#  'fxify',
#  'south ealing gay',
#  'double ended bath x',
#  'magical',
#  'toyota granvia',
#  'skate shoes',
#  'garden cart',
#  'best if british board game',
#  'kids wardrobe',
#  'resonator',
#  'fire surrounde',
#  'bio fuel',
#  'small vans mother',
#  'ft bed base',
#  'evacuation chair',
#  'maidatone',
#  'looking for home help',
#  'muck truck',
#  'harlequin rabbit',
#  'surefeed feeder',
#  'samsung led monitor',
#  'horny asian girl will make your dreams come true available daily am to pm',
#  'generator v petrol',
#  'citroen berlingo rear seats',
#  'copl',
#  'band saw',
#  'lugworm pump',
#  'dyson fan',
#  'topless',
#  'american bull dog',
#  'bn qn',
#  'proogas bottles',
#  'aberdeen trans',
#  'chub',
#  'bathroom chair',
#  'seter',
#  'single mattress emma',
#  'nsa trans',
#  'sony nex',
#  'indepndente',
#  'and tl',
#  'roof rack audi',
#  'baby poodle',
#  'eservice o s',
#  'dirty chat',
#  'redbri',
#  'tostarp wall light',
#  'adult massag e',
#  'polit commander watch',
#  'massage in somerset',
#  'fold up bikes',
#  'minton bone china plates',
#  'nun costume',
#  'm bmq',
#  'copthorne guide',
#  'dog and puppies',
#  'push bike',
#  'rollof lino',
#  'track saw',
#  'tonby',
#  'asian bangladeshi indian',
#  'artwork',
#  'trajc',
#  'afr',
#  'samsung s ultra',
#  'touras caravan',
#  'ip',
#  'angel fish',
#  'rrom',
#  'dara',
#  'superking duvet',
#  'sex massagecanterburtu',
#  'switch mod',
#  'single room to rent in hastings',
#  'ts liverp',
#  'german shepherds',
#  'lunch box',
#  'garden strimmers',
#  'call out girls',
#  'prositutes',
#  'nuru massage in southampton',
#  'erotic masssge',
#  'leek',
#  'unloaded speaker cabinet',
#  'mobylette',
#  'vxr',
#  'park home near crawley west sussex',
#  'hairy pussy',
#  'fender strat black white guitar',
#  'hertfordshi',
#  'black ass',
#  'shelf cupboard unit',
#  'well',
#  'valentina cruz',
#  'nova light',
#  'escort hookup',
#  'free',
#  'general manager',
#  'free vivarium',
#  'suziki',
#  'armr mens motor cycle jacket',
#  'large dog crate',
#  'red leather jacket',
#  'oriental erscorts full gfe',
#  'cutlery cabinet',
#  'mobile hairdressing',
#  'folding scooter',
#  'hoop up',
#  'joy on',
#  'honda ctx',
#  'womens safety boots',
#  'potterto gas boiler',
#  'king size wooden bed frame',
#  'dna amazing tamed hyacinth macaw parrots for sale',
#  'miajoan',
#  'group s',
#  'vw polo automatic',
#  'mo els',
#  'slot machine',
#  'stud shih tzu',
#  'african grey bird',
#  'cat cages',
#  'helna',
#  'horsham double bed',
#  'in call es',
#  'how much to sell my car',
#  'wolvehmpton',
#  'wood gree',
#  'wax oil',
#  'durham escorts female',
#  'bilbo t campervan',
#  'fencer to mend gate post',
#  'leather jeans',
#  'jaguqr',
#  'necklace',
#  'mens bicycles',
#  'pentax mx camera',
#  'tanya thai southend',
#  'ipod',
#  'black decker battery charger',
#  'nn eu for sale',
#  'pat tester for sale',
#  'adult massage brighton',
#  'polly pockets',
#  'hemnes',
#  'oil fired aga technichens',
#  'clapham',
#  'bikes for adults',
#  'beautiful blue brittish shorthair kittens',
#  'giant teddy',
#  'mobile jo',
#  'oana p',
#  'cock waxing',
#  'laptop buyers',
#  'shakura',
#  'bostn',
#  'ft christmas tree',
#  'general yard staff',
#  'wheelchair cars',
#  'wooden double bed frame',
#  'teen gay',
#  'thick plastic pipe',
#  'york stone',
#  'beautiful tricoloured cob',
#  'citroen berlingo multispace',
#  'toulet seat raiser',
#  'bed flat for tent',
#  'inch tv',
#  'indoor camera',
#  'fantail',
#  'shelves or cabinet',
#  'bissell',
#  'independent chubby escort',
#  'campervan',
#  'carbon track disc wheel',
#  'sexy latin',
#  'licking',
#  'adult contact south wales',
#  'secure parking',
#  'air rifel parts',
#  'farham',
#  'hall tables',
#  'gas fitters',
#  'spanking escorts',
#  'tantrs',
#  'felipa',
#  'jawa',
#  'rental units in newhaven',
#  'conveyer toaster',
#  'double bed with mattress',
#  'horror figures',
#  'vr oculas',
#  'electric cycles',
#  'massage service in surrey',
#  'car roof bars',
#  'pin bowling ball bag',
#  'jenn',
#  'things for free',
#  'metal filing cabinets',
#  'small bottles',
#  'disabled bath',
#  'jumperoo',
#  'fridge magnets',
#  'hand tools',
#  'katies',
#  'white poodle cross looks poodle needs a new home male years',
#  'ruffwear',
#  'dormitor cu mobila',
#  'bausch lomb',
#  'ikea drawer',
#  'naughtyalessia',
#  'stealth wood senior shaft',
#  'one bedroom flat for rent',
#  'galaxy tablet',
#  'tibetan mastiff puppy',
#  'hook up sex kirkby',
#  'fake',
#  'titwank',
#  'folks wagon polo',
#  'sexual mas',
#  'acrylic worktops',
#  'bmw cdi convertible',
#  'cats for adoption in sussex',
#  'upscale door',
#  'pioneer xz',
#  'rubber floor mats large',
#  'domestic and commercial cleaning',
#  'second hand electric cookers',
#  'nursing chair',
#  'naturist house share',
#  'women in tavistock',
#  'funko',
#  'magure british',
#  'old english sheepdog',
#  'tesla s',
#  'granny wanting cock',
#  'x puppies',
#  'adult female sex contacts',
#  'shisha pipe',
#  'prius alpha',
#  'coat',
#  'men old',
#  'dark furniture',
#  'yamaha portatone keyboard',
#  'diability access car',
#  'sexymilfbrighton',
#  'babby rabbits',
#  'knitting machines',
#  'toshiba combi dvd player and recorder',
#  'granite',
#  'female escort cheshire',
#  'chef jobs',
#  'missters',
#  'cordless stick vacuum',
#  'sq ft secure workshop storage',
#  'car roofbars',
#  'touch of class massage',
#  'picture mount cutter kit',
#  'baxi fire',
#  'uremovals',
#  'online translator',
#  'boxer poppy',
#  'chars',
#  'dad hound',
#  'london earle s court',
#  'sexual services',
#  'pixel watch lte',
#  'stortford',
#  'fucking',
#  'gay essex',
#  'painters crawley',
#  'glider',
#  'portland',
#  'front doors',
#  'bully s puppies',
#  'tool box s',
#  'escort coventry',
#  'adult aervics',
#  'handyman hove',
#  'pocket billy',
#  'bakelite phone',
#  'deep fat fryer',
#  'car insurance',
#  'dispatch operator',
#  'oriental chinese trunk',
#  'chinees painted quail',
#  'chubby',
#  'escort geys',
#  'little dogue de bordeaux puppies',
#  'thomas bennett school uniform',
#  'peugeot automatic owner from new',
#  'three seater suet',
#  'writing desk computer desk',
#  'free to good home',
#  'exciting new livery yard in cobham stoke d',
#  'pyramid oil can',
#  'borough',
#  'manch',
#  'washing merchine',
#  'train sets hornby',
#  'tunbridge wells dogging',
#  'electric piano with weighted keys',
#  'golden retriever puppy',
#  'sw sb',
#  'escort duo windsor',
#  'cheap cats',
#  'single matress',
#  'coal cage',
#  'voucher',
#  'corn',
#  'spider man bike',
#  'freelander luggage cover',
#  'motorcycle spares repair',
#  'slut',
#  'sylvanian family',
#  'single bed fr',
#  'this car is in immaculate condition',
#  'black male kitten',
#  'northeast uk',
#  'vauxhall astra space saver',
#  'mis',
#  'adultservives',
#  'redhil',
#  'peugeot parts window regulator',
#  'cat whicker basket',
#  'exo viv',
#  'south queensferry',
#  'tran sexual',
#  'massage bedford',
#  'bosch garden shredder',
#  'playstation console',
#  'invertor generator',
#  'koga world',
#  'bmw i convertible manual',
#  'small shed',
#  'video porn',
#  'battle',
#  'woodley rg',
#  'psilocybin',
#  'various commercial warehouses units storage facilities',
#  'cricket equipments',
#  'italian grey hound',
#  'wall shelving',
#  'bedroom flat to rent in elizabeth court mill road worthing bn',
#  'mat',
#  'nsa hookup',
#  'lgv driver',
#  'classified papers',
#  'day trading',
#  'mini clubvan',
#  'farnh',
#  'tanning salon for sale',
#  'glossop',
#  'escorts near ramsgate',
#  'she',
#  'metal aviary',
#  'air gun silencer',
#  'sexy doctor',
#  'very quiet air compressor',
#  'pinkey',
#  'ladies ping golf club s',
#  'fiesta spares repairs',
#  'looking for holiday l',
#  'chaise lounges',
#  'escort in ba area',
#  'looking to',
#  'renting house',
#  'toyota prius seater',
#  'industry worker',
#  'netherland dabbits',
#  'a good size double room with double bed and a large fitted wardrobe',
#  'kitchen furniture used',
#  'guitar pickups',
#  'jaguar xf',
#  'adult service eastbourne',
#  'northamptonshire',
#  'findom',
#  'brindle puppys',
#  'male massage derby',
#  'folding bikr',
#  'ou',
#  'local blonde',
#  'cherry g',
#  'mopeds scooters',
#  'garage to rent in redhill',
#  'brigton eduction service',
#  'dehumidifier like your channel',
#  'loughton',
#  'losa',
#  'bedroom property rent',
#  'hairy polish',
#  'unwanted',
#  'staffordshire bull terrier cross xl bully',
#  'fista',
#  'make massaeg',
#  'carftfair',
#  'chair rent',
#  'freelance writing jobs',
#  'free a',
#  'mink caravan',
#  'mercedes parts',
#  'way fridge',
#  'gutter vac',
#  'audi q',
#  'givi top box',
#  'selling due to upgrade',
#  'kenwood hifi',
#  'paddle',
#  'atherstone',
#  'deagostini farm',
#  'stunning welsh terrier male neutered years',
#  'black and silver metal bed frame',
#  'gay weybr',
#  'erotic services',
#  'epns',
#  'massage south east london',
#  'cob gelding',
#  'wooden milking stool',
#  'camper vans cheap',
#  'suv west sussex',
#  'how',
#  'private math teacher',
#  'touring',
#  'chonzer',
#  'mums',
#  'minstead',
#  'ford kuga towbar',
#  'adult swingers clubs',
#  'sideboard beech',
#  'part time barista bistro attendant',
#  'belle wacker plate',
#  'hamaster',
#  'pram and pushchair',
#  'ec',
#  'carnaby champagne',
#  'scottishmaturekat',
#  'mobility walkers',
#  'honda cbr rr',
#  'thai massa',
#  'falabella',
#  'escort cr',
#  'hyundai terracan',
#  'k firestick',
#  'leaflet distributor required for steyning and the surrounding area',
#  'bmx bike new',
#  'echo dot',
#  'renault clio campus',
#  'turkish takla',
#  'pocket watches',
#  'diamonds',
#  'home dect phone',
#  'bruna patricia',
#  'classic bus magazine',
#  'shetland sheepdog',
#  'red dress',
#  'cream chargers',
#  'male escort massage job',
#  'lonely hearts ads',
#  'finance advisor',
#  'hamster glass cage',
#  'steam shower',
#  'tonpai massage',
#  'electric coffee percultor',
#  'airsoft gun',
#  'leather chesterfield sofa',
#  'kettle bell',
#  'cm massage',
#  'ell en',
#  'pine welsh dresser',
#  'scarcity studios',
#  'black male escort',
#  'handmade lamps',
#  'estt london',
#  'hummer h',
#  'wishbone chair',
#  'kids rug',
#  'west byleetf',
#  'citroen c vtr',
#  'muslim girls',
#  'delta sienna',
#  'rosie bbw',
#  'adult walthamstow',
#  'sensual massage center for men',
#  'aga oven',
#  'sewing alterations',
#  'male massage for men only',
#  'peyer',
#  'bevan dean',
#  'blue ray players',
#  'erotic sensual massage',
#  'who o',
#  'b b b massage',
#  'luna lexon sb',
#  'peterborough seductive cute oriental party girl',
#  'accuphase e',
#  'bluespark',
#  'ladies guess watches',
#  'findon rd worthing west sussex bn ab uk',
#  'wade',
#  'stewart mouland motorcravans',
#  'drawer',
#  'adult services kelly',
#  'carrera cross city',
#  'warmblood',
#  'vw tranporter',
#  'volvo xc v',
#  'disco hire',
#  'massage services farnborough',
#  'butchers',
#  'malm chest drawer',
#  'hay needed',
#  'pinarello',
#  'wek',
#  'adult mee',
#  'audi q roo bars',
#  'mature escourts',
#  'laura ashley chenille',
#  'plumbing fitting',
#  'stock car',
#  'massage palour',
#  'twins',
#  'under wear',
#  'private static caravan',
#  'hheel drive',
#  'vintage cupboards',
#  'frog',
#  'john lewis rug hold underlay',
#  'ladies golf',
#  'smart roadster racing edition',
#  'olde english bulldog puppy',
#  'sony r',
#  'mini ipad',
#  'gilera runner scooter',
#  'compass rambler berth low mileage',
#  'pipe',
#  'alison davidson',
#  'self employed jobs',
#  'tires',
#  'wanted dehumifier',
#  'free tank',
#  'tn df',
#  'ps console',
#  'pakistan girls',
#  'reptile vivarums',
#  'lupo gti',
#  'van for hire',
#  'bodmin',
#  'brent cross',
#  'cordless garden leaf',
#  'ring camera',
#  'local gardener in hove',
#  'pegeut',
#  'cartralers',
#  'cc mopeds',
#  'exercise machines',
#  'muscovy ducks and ducklings',
#  'rtm duo tanden kayak',
#  'buying naughty picture online',
#  'finger monkey',
#  'rattan corner settee',
#  'vivamk',
#  'persian ragdoll',
#  'pine double wardrobe',
#  'swift suntor motorhome',
#  'dogs puppy',
#  'braintree escorts',
#  'renting room',
#  'john lewis oak dining table',
#  'wireless guitar',
#  'under part time',
#  'outdoor christmas decorations',
#  'helmets',
#  'pads',
#  'chester motorhomes',
#  'timber building manufacturer and erector',
#  'front door and surround',
#  'garden appliances',
#  'lsa glasses',
#  'golf carry bag',
#  'field space',
#  'independent massage escort',
#  'spekers',
#  'vintage valve radio',
#  'be passat estate',
#  'lesbian sensual massage',
#  'peogeot',
#  'sell my laptop',
#  'washing machine for sale',
#  'rock',
#  'free lander cars',
#  'flat tolet',
#  'staff puppies',
#  'security officers hour gatwick airport',
#  'portable gas fire',
#  'cb antenna',
#  'large suitcase with wheels',
#  'furniture removals',
#  'ellis caravan',
#  'ikea aneboda wardrobe',
#  'free dick',
#  'boot fairs local',
#  'superking bed frame',
#  'short wedding dress',
#  'reclining',
#  'gerbils related male and female',
#  'peugeot teepee',
#  'first time',
#  'fridge magnet',
#  'limousines',
#  'large snake tank',
#  'peougeot suv',
#  'used auto cars',
#  'snd',
#  'threesome escort',
#  'scort lady',
#  'lady birds',
#  'private security',
#  'granny from essex',
#  'lovely king charles pups for sale',
#  'caravan gas bottles',
#  'corner sofa bed',
#  'boot sales hastings',
#  'central asian shepeard',
#  'ukulele',
#  'massage westcliff on sea',
#  'ski jacket brighton',
#  'women nottingham',
#  'amy s massage',
#  'thsi',
#  'rent space',
#  'ride on toy',
#  'my juciy diting com',
#  'shirts',
#  'rug carpet',
#  'worktop',
#  'hernehill',
#  'plastic table',
#  'travel system',
#  'tn de',
#  'dials',
#  'huyu',
#  'staffs puppy s',
#  'fridge truck',
#  'mowbray court hotel',
#  'adult serivice',
#  'independa',
#  'vtech phone',
#  'hand held inkjet gun',
#  'naughty',
#  'yorkshire biewer',
#  'deep kisser',
#  'reliable experienced cleaner',
#  'eurocruiser',
#  'new milfs',
#  'piano tuner',
#  'massage eastbounre',
#  'women offering sex',
#  'internal door',
#  'n guage railway',
#  'office studio',
#  'chinese massage redhill',
#  'greenhouse glass',
#  'female ginger kittens',
#  'tow bar bike rack',
#  'lawncare',
#  'linkin park',
#  'plentysocial',
#  'escorts out',
#  'home help cleaner required per hour',
#  'trans adults',
#  'k monitor',
#  'thorthon heat',
#  'chord dac',
#  'patient transfer board',
#  'hitachi sdt',
#  'phone number phone numbers for prostitutes in bognor',
#  'swindon cylces',
#  'removal',
#  'quaker pattot',
#  'scola artmix paint',
#  'ds games',
#  'hiundai i',
#  'home care lewes',
#  'audi a s parts',
#  'model work',
#  'fabia',
#  'gayhot lines',
#  'motor trade garage worthing',
#  'beautician',
#  'drum filter',
#  'sex in burgess hill',
#  'rent apartments',
#  'late nights massage',
#  'bedroom flat to rent in park crescent worthing bn',
#  'freelander land rover',
#  'metal cupboards',
#  'oak door',
#  'controller',
#  'citroen xsara picasso vtx v l unleaded',
#  'indoor pots',
#  'im tegan the sexy tiger come and visit me for fun',
#  'a desk',
#  'full size fridge freezer',
#  'folding pool',
#  'house cleaning',
#  'single sofa bed',
#  'pride colt es mobility scooter',
#  'camping gear',
#  'garage repair',
#  'chickens',
#  'full time nanny',
#  'hour massage',
#  'secondhand kitchen',
#  'walton on thames',
#  'lenna hoston',
#  'reanult clio',
#  'mam',
#  'gas powered bb gun',
#  'tantric massa',
#  'ryobi drills',
#  'jumble sale th january',
#  'older women over',
#  'black woman croydon',
#  'baileys job',
#  'renault grand scenic drive',
#  'plumhead parrots',
#  'dirty escorts',
#  'escort massa',
#  'chat line staff to work from home good rates',
#  'transgender',
#  'gay massgea',
#  'ski carrier',
#  'nuneaton',
#  'alpha romeo mito',
#  'dancers required for exclusive private club in brighton',
#  'cardboard moving boxes',
#  'double mattress for sale',
#  'holiday chalet',
#  'amazon fire hd th gen gb wi fi black with ads',
#  'islinton',
#  'rabbit',
#  'cool bag',
#  'mens bicycle',
#  'electric bycycles',
#  'honeys portslade',
#  'kirkdale',
#  'high pressure power washer',
#  'dog ramps',
#  'honda jaz',
#  'cricketwood',
#  'samson',
#  'ct gold cross and necklace',
#  'kompleter',
#  'pravite',
#  'teesdale tree services',
#  'meadow hay',
#  'prostitutes littlehampton',
#  'ulez van',
#  'hitch lock trailer',
#  'aqa sociology book',
#  'rented accommodation',
#  'swimming pool builders',
#  'metal action sofa bed',
#  'room hire',
#  'camping gas bottle',
#  'flagon',
#  'rural workshop storage available in hartfield tn',
#  'moving service',
#  'learning',
#  'slough',
#  'double garage for rent',
#  'adorable english bulldog for sale',
#  'large dog crest',
#  'transsexuals crossdressers and tvs for the night',
#  'puppy laboratory',
#  'dog regime',
#  'king charles',
#  'jaguar f pace',
#  'blu rays',
#  'beds',
#  'mercedes amg',
#  'side table gold legs',
#  'forest hill',
#  'upscale door and frame',
#  'leather gear',
#  'khao manee',
#  'led television',
#  'aquaroll water',
#  'mirror with lights',
#  'citroen dispatch breaking',
#  'tutees',
#  'rolling stones',
#  'black bio orb fish tank stand',
#  'japanese jewellery box',
#  'tea trolly',
#  'thai massag',
#  'wells',
#  'side by side fridge freezer',
#  'caravan window',
#  'only camberley girl',
#  'bed house to private rent',
#  'goldfinch',
#  'brog',
#  'chestnut',
#  'margate asian',
#  'pugeons',
#  'skiers edge',
#  'office berkhamstead',
#  'bailey unicorn cabrera',
#  'cybex car seat',
#  'vivarium cabinet',
#  'driving class',
#  'abt',
#  'cache lx s rcqiuj https www friday ad co uk faredealspot travel agents abbots langley staycations',
#  'husky puppy',
#  'car seat cover',
#  'ces',
#  'to sell',
#  'nice bristol roofing company',
#  'rent crawley',
#  'milwakee',
#  'ford fiesta spoiler',
#  'nzx',
#  'commonde',
#  'extra ball',
#  'wooden trains',
#  'computa lessons',
#  'large corner sofa',
#  'ranbit',
#  'slut girls',
#  'short escort',
#  'tall larder unit',
#  'tracked dumpers',
#  'pride village party wristbands',
#  'fleet hampshire',
#  'kitcheeen cabinets',
#  'rabbits lowestoft',
#  'labrador cross',
#  'peugeot accessibility',
#  'personal messages',
#  'cars under four thousand pounds',
#  'smart barabbas',
#  'watersport',
#  'seat ibiza tsi petrol door',
#  'x garden shed',
#  'adult services highe wycombe',
#  'small bale hay',
#  'golf irona',
#  'fake money',
#  'escort horsham',
#  'uk escorts',
#  'oriental tounge tip massage',
#  'camper van heater',
#  'escort dover',
#  'hotel receptionist',
#  'surround sound system',
#  'chrst of drawers',
#  'shopper bike',
#  'cars wantes',
#  'hoist winch',
#  'bmk powder',
#  'haroldwood',
#  'sylvanian families characters',
#  'video call sex',
#  'teddy guinea pigs',
#  'bedroom flat to rent in bexhill on sea',
#  'birthcaravan',
#  'standard vanguard panel van',
#  'cat stuff',
#  'piano sheet music',
#  'bj no plate',
#  'shelves metal',
#  'toilet training',
#  'free sand',
#  'cloth ironing',
#  'motor parts',
#  'puppet',
#  'devon tantric massage',
#  'avanti method feeder',
#  'as r',
#  'electeic oven',
#  'dehli',
#  'littlecaaprice',
#  'suzuki grand vitara',
#  'toyota yaris',
#  'massaabge a dul',
#  'studio bedsitting room in the green st leonard',
#  'handy man needed',
#  'ativan',
#  'princess of wales',
#  'copper',
#  'ramps for scooter',
#  'anal granny',
#  'portable massage chair',
#  'philipino',
#  'escorts kingston upon th',
#  'maratnz',
#  'sweet pomeranian puppy for sale weeks old',
#  'whatsapp contacts',
#  'york escorts',
#  'royal bed',
#  'adult only',
#  'electric sander',
#  'pervert',
#  'dog for rehoming',
#  'storage bench',
#  'samsung galaxy flip',
#  'laminator',
#  'tilly lamp',
#  'massage with abbey',
#  'om',
#  'rod and reel',
#  'ella wren',
#  'writing desk',
#  'hello horny gents i',
#  'bmw d start stop stunning car',
#  'kitchen worktop supply',
#  'sander polisher',
#  'escirt',
#  'mob bikes',
#  'encountres',
#  'relationship tarot',
#  'staffordshire bull terroir dog',
#  'sex escorting oxford',
#  'post mouth adults',
#  'bmw e wind deflector',
#  'twilight',
#  'child stair gate',
#  'bill np billingshurst farm conversion industrial units',
#  'storage basket table',
#  'deepthroats',
#  'pakistan girl',
#  'wooden play table',
#  'massage walsall',
#  'pur',
#  'midwinter wild oats china',
#  'thai massage brighton',
#  'persanals ladys',
#  'sheds secondhand',
#  'length',
#  'lawn mower engine',
#  'mini digger buckets',
#  'wedding flowers',
#  'drum kits',
#  'garden rotator',
#  'steel toe',
#  'apprentice',
#  'casas venda perto eastborne',
#  'mileage correction',
#  'free fuck mature contact',
#  'tor',
#  'adria',
#  'ssmsung a mobile phone',
#  'footstools',
#  'harley davidson shield',
#  'xone',
#  'health and beauuty',
#  'neco cc',
#  'shadwell',
#  'mature sex dates essex',
#  ...]

# %% [markdown]
# ## Vectorizer and term_matrix

# %%
stpwrd = nltk.corpus.stopwords.words('english')

# %%
count_vectorizer = CountVectorizer(stop_words = stpwrd, max_features = 4000)

# %%
document_term_matrix = count_vectorizer.fit_transform(clean_list)

# %%
document_term_matrix
# Out:
# <65424x4000 sparse matrix of type '<class 'numpy.int64'>'
# 	with 112630 stored elements in Compressed Sparse Row format>

# %%
print('Content after vectorization: \n{}'.format(document_term_matrix))
# Out:
# Content after vectorization:
#   (1, 3160)	1
#   (1, 256)	1
#   (1, 224)	1
#   (1, 1032)	1
#   (2, 561)	1
#   (2, 1777)	1
#   (2, 2685)	1
#   (4, 1443)	1
#   (5, 1489)	1
#   (5, 3343)	1
#   (6, 3747)	1
#   (6, 3564)	1
#   (7, 2866)	1
#   (7, 1415)	1
#   (7, 389)	1
#   (8, 1777)	1
#   (8, 1412)	1
#   (9, 2866)	1
#   (9, 258)	1
#   (9, 2734)	1
#   (10, 3990)	1
#   (10, 3521)	1
#   (10, 2757)	1
#   (10, 2981)	1
#   (11, 1208)	1
#   :	:
#   (65408, 3305)	1
#   (65408, 3325)	1
#   (65409, 1674)	1
#   (65412, 1349)	1
#   (65412, 2083)	1
#   (65412, 3837)	1
#   (65413, 1329)	1
#   (65413, 3645)	1
#   (65414, 1174)	1
#   (65414, 820)	1
#   (65416, 2977)	1
#   (65416, 1411)	1
#   (65416, 1650)	1
#   (65417, 1220)	1
#   (65417, 867)	1
#   (65417, 2042)	1
#   (65418, 3835)	1
#   (65419, 3674)	1
#   (65419, 1496)	1
#   (65420, 565)	1
#   (65422, 673)	1
#   (65422, 1668)	1
#   (65423, 1410)	1
#   (65423, 372)	1
#   (65423, 2061)	1

# %% [markdown]
# ## LDA

# %%
lda = LatentDirichletAllocation(n_components=5, random_state=42) 
lda.fit(document_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
for i,topic in enumerate(lda.components_): 
    print(f'Topic #{i}:') 
    print([count_vectorizer.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Topic #0:
# ['call', 'home', 'double', 'escort', 'girl', 'garden', 'girls', 'bed', 'free', 'escorts']
#
#
# Topic #1:
# ['body', 'service', 'electric', 'tv', 'women', 'ford', 'table', 'sex', 'escort', 'massage']
#
#
# Topic #2:
# ['sale', 'sussex', 'kittens', 'sofa', 'old', 'jobs', 'black', 'bike', 'puppies', 'male']
#
#
# Topic #3:
# ['kitchen', 'automatic', 'van', 'services', 'room', 'chairs', 'cars', 'wanted', 'dog', 'adult']
#
#
# Topic #4:
# ['wood', 'machine', 'men', 'caravan', 'bedroom', 'house', 'flat', 'car', 'sale', 'rent']

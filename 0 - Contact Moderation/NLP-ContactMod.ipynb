# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re

warnings.filterwarnings('ignore')

# %%
email = pd.read_csv('/Users/rajathadri_as/Documents/Email05_25-09-23.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
email.head()
# Out:
#    ModerationReportId  ModerationAction  BannedRecipientNotificationRequired  \
# 0                   1                 6                                    0
# 1                   4                 6                                    0
# 2                   7                 6                                    0
# 3                  10                 3                                    0
# 4                  13                 3                                    0
#
#    ManuallyModeratedBy       ModerationDate  OverrideType  \
# 0                  8.0  2023-07-19 06:31:26           NaN
# 1                  8.0  2023-07-19 06:31:28           NaN
# 2                  8.0  2023-07-19 06:31:29           NaN
# 3                  NaN  2023-07-19 06:06:18           NaN
# 4                  NaN  2023-07-19 06:07:10           NaN
#
#    GateKeeperModerationAction                      Sender  \
# 0                           5         deji90673@gmail.com
# ...

# %%
email.shape
# Out:
# (111543, 26)

# %%
email.SourceType.value_counts()
# Out:
# SourceType
# 0    92146
# 1    19397
# Name: count, dtype: int64

# %%
email.drop(['ManuallyModeratedBy','OverrideType','References','AdvertUrl','AdRef'],axis=1, inplace=True)

# %%
email[['ModerationDate','DateSent']] = email[['ModerationDate','DateSent']].astype('datetime64[ns]')

# %%
email.isnull().sum()
# Out:
# ModerationReportId                         0
# ModerationAction                           0
# BannedRecipientNotificationRequired        0
# ModerationDate                             0
# GateKeeperModerationAction                 0
# Sender                                     0
# Recipient                                  0
# Subject                                 2845
# Body                                     127
# MostRecentMessage                        127
# DateSent                                   0
# EmailStatus                                0
# IPAddress                              19834
# Country                                28479
# OriginatingSiteId                          0
# ThreadId                                   0
# LanguageCode                               0
# VersionType                                0
# SpfValidationResult                        0
# SourceType                                 0
# SiteName                                   0
# ...

# %%
email['Body'].fillna('nil', inplace=True)
email['MostRecentMessage'].fillna('nil', inplace=True)
email['IPAddress'].fillna('0', inplace=True)
email['Subject'].fillna('NoSubject', inplace=True)
email['Country'].fillna('NoCountry', inplace=True)

# %%
email.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111543 entries, 0 to 111542
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ModerationReportId                   111543 non-null  int64
#  1   ModerationAction                     111543 non-null  int64
#  2   BannedRecipientNotificationRequired  111543 non-null  int64
#  3   ModerationDate                       111543 non-null  datetime64[ns]
#  4   GateKeeperModerationAction           111543 non-null  int64
#  5   Sender                               111543 non-null  object
#  6   Recipient                            111543 non-null  object
#  7   Subject                              111543 non-null  object
#  8   Body                                 111543 non-null  object
#  9   MostRecentMessage                    111543 non-null  object
# ...

# %%
mods = pd.read_csv('/Users/rajathadri_as/Documents/Mods05_25-09-23.csv')

# %%
mods.head()
# Out:
#    ModerationReportId  ModerationAction  BannedRecipientNotificationRequired  \
# 0                   1                 6                                    0
# 1                   4                 6                                    0
# 2                   7                 6                                    0
# 3                  10                 3                                    0
# 4                  13                 3                                    0
#
#    RedactedEmailNotificationRequired  ManuallyModeratedBy  \
# 0                                  0                  8.0
# 1                                  0                  8.0
# 2                                  0                  8.0
# 3                                  0                  NaN
# 4                                  0                  NaN
#
#         ModerationDate  ManualRejectionReasonId  OverrideType  Email_EmailId  \
# ...

# %%
mods.shape
# Out:
# (118803, 16)

# %%
mods.isnull().sum()
# Out:
# ModerationReportId                          0
# ModerationAction                            0
# BannedRecipientNotificationRequired         0
# RedactedEmailNotificationRequired           0
# ManuallyModeratedBy                    102241
# ModerationDate                              0
# ManualRejectionReasonId                118803
# OverrideType                           118732
# Email_EmailId                               0
# GateKeeperModerationAction                  0
# ModeratorType                           94284
# MatchedCriteria                         94284
# Description                            101483
# Occurrences                             94284
# MatchedRuleSetId                        94284
# ModuleType                              94284
# dtype: int64

# %%
mods.drop(['ManuallyModeratedBy','ManualRejectionReasonId','OverrideType','ModeratorType','MatchedCriteria','Description','Occurrences','MatchedRuleSetId'],axis=1, inplace=True)

# %%
mods[['ModerationDate']] = email[['ModerationDate']].astype('datetime64[ns]')

# %%
mods.isnull().sum()
# Out:
# ModerationReportId                         0
# ModerationAction                           0
# BannedRecipientNotificationRequired        0
# RedactedEmailNotificationRequired          0
# ModerationDate                          7260
# Email_EmailId                              0
# GateKeeperModerationAction                 0
# ModuleType                             94284
# dtype: int64

# %%
mods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118803 entries, 0 to 118802
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ModerationReportId                   118803 non-null  int64
#  1   ModerationAction                     118803 non-null  int64
#  2   BannedRecipientNotificationRequired  118803 non-null  int64
#  3   RedactedEmailNotificationRequired    118803 non-null  int64
#  4   ModerationDate                       111543 non-null  datetime64[ns]
#  5   Email_EmailId                        118803 non-null  int64
#  6   GateKeeperModerationAction           118803 non-null  int64
#  7   ModuleType                           24519 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(6)
# memory usage: 7.3 MB

# %%
email.drop(['ModerationAction','ModerationDate','BannedRecipientNotificationRequired','GateKeeperModerationAction'],axis=1, inplace=True)

# %%
email.isnull().sum()
# Out:
# ModerationReportId     0
# Sender                 0
# Recipient              0
# Subject                0
# Body                   0
# MostRecentMessage      0
# DateSent               0
# EmailStatus            0
# IPAddress              0
# Country                0
# OriginatingSiteId      0
# ThreadId               0
# LanguageCode           0
# VersionType            0
# SpfValidationResult    0
# SourceType             0
# SiteName               0
# dtype: int64

# %%
df = mods.merge(email, on = 'ModerationReportId', how = 'left')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118803 entries, 0 to 118802
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   ModerationReportId                   118803 non-null  int64
#  1   ModerationAction                     118803 non-null  int64
#  2   BannedRecipientNotificationRequired  118803 non-null  int64
#  3   RedactedEmailNotificationRequired    118803 non-null  int64
#  4   ModerationDate                       111543 non-null  datetime64[ns]
#  5   Email_EmailId                        118803 non-null  int64
#  6   GateKeeperModerationAction           118803 non-null  int64
#  7   ModuleType                           24519 non-null   float64
#  8   Sender                               118798 non-null  object
#  9   Recipient                            118798 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ModerationReportId                         0
# ModerationAction                           0
# BannedRecipientNotificationRequired        0
# RedactedEmailNotificationRequired          0
# ModerationDate                          7260
# Email_EmailId                              0
# GateKeeperModerationAction                 0
# ModuleType                             94284
# Sender                                     5
# Recipient                                  5
# Subject                                    5
# Body                                       5
# MostRecentMessage                          5
# DateSent                                   5
# EmailStatus                                5
# IPAddress                                  5
# Country                                    5
# OriginatingSiteId                          5
# ThreadId                                   5
# LanguageCode                               5
# VersionType                                5
# ...

# %%
df.shape
# Out:
# (118803, 24)

# %%
df.head()
# Out:
#    ModerationReportId  ModerationAction  BannedRecipientNotificationRequired  \
# 0                   1                 6                                    0
# 1                   4                 6                                    0
# 2                   7                 6                                    0
# 3                  10                 3                                    0
# 4                  13                 3                                    0
#
#    RedactedEmailNotificationRequired      ModerationDate  Email_EmailId  \
# 0                                  0 2023-07-19 06:31:26             25
# 1                                  0 2023-07-19 06:31:28             28
# 2                                  0 2023-07-19 06:31:29             31
# 3                                  0 2023-07-19 06:06:18              1
# 4                                  0 2023-07-19 06:07:10              7
#
# ...

# %%
df = df[df['LanguageCode']=='en']

# %%
df.drop(['ModerationReportId','ModerationDate','BannedRecipientNotificationRequired','RedactedEmailNotificationRequired','ModerationDate','LanguageCode','VersionType'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  ModuleType  \
# 0                 6             25                           5         3.0
# 1                 6             28                           5         3.0
# 2                 6             31                           5         3.0
# 3                 3              1                           5         NaN
# 4                 3              7                           5         NaN
#
#                        Sender                          Recipient  \
# 0         deji90673@gmail.com              heidswood@hotmail.com
# 1         deji90673@gmail.com              promedia333@gmail.com
# 2         deji90673@gmail.com          hawkinsleslie69@yahoo.com
# 3                me@enuuu.com  marta.markow@fridaymediagroup.com
# 4  rebecca0607evans@gmail.com            herby432001@yahoo.co.uk
#
#                                              Subject  \
# 0  Message regarding ad: Extremely reliable car. ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115991 entries, 0 to 118797
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ModerationAction            115991 non-null  int64
#  1   Email_EmailId               115991 non-null  int64
#  2   GateKeeperModerationAction  115991 non-null  int64
#  3   ModuleType                  24068 non-null   float64
#  4   Sender                      115991 non-null  object
#  5   Recipient                   115991 non-null  object
#  6   Subject                     115991 non-null  object
#  7   Body                        115991 non-null  object
#  8   MostRecentMessage           115991 non-null  object
#  9   DateSent                    115991 non-null  datetime64[ns]
#  10  EmailStatus                 115991 non-null  float64
#  11  IPAddress                   115991 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# ModerationAction                  0
# Email_EmailId                     0
# GateKeeperModerationAction        0
# ModuleType                    91923
# Sender                            0
# Recipient                         0
# Subject                           0
# Body                              0
# MostRecentMessage                 0
# DateSent                          0
# EmailStatus                       0
# IPAddress                         0
# Country                           0
# OriginatingSiteId                 0
# ThreadId                          0
# SpfValidationResult               0
# SourceType                        0
# SiteName                          0
# dtype: int64

# %%
df.ModerationAction.value_counts()
# Out:
# ModerationAction
# 3    106475
# 0      8639
# 6       871
# 2         6
# Name: count, dtype: int64

# %%
df.OriginatingSiteId.value_counts()
# Out:
# OriginatingSiteId
# 14.0    47494
# 34.0    17919
# 1.0     17656
# 16.0    11365
# 8.0      6446
# 17.0     4446
# 30.0     3718
# 41.0     1602
# 36.0     1579
# 40.0     1402
# 38.0      950
# 23.0      806
# 29.0      212
# 46.0      190
# 15.0      185
# 42.0       19
# 3.0         2
# Name: count, dtype: int64

# %%
df['Subject'] = df['Subject'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df['MostRecentMessage'] = df['MostRecentMessage'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df['Body'] = df['Body'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df['Country'] = df['Country'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df['ThreadId'] = df['ThreadId'].apply(lambda x: x.lower() if isinstance(x, str) else x)

# %%
import string
# Define punctuation characters
punct_chars = set(string.punctuation)

# Apply regex pattern to text column
df['Subject'] = df['Subject'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))
df['MostRecentMessage'] = df['MostRecentMessage'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))
df['Body'] = df['Body'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))
df['Country'] = df['Country'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))
df['ThreadId'] = df['ThreadId'].apply(lambda x: ''.join(char for char in x if char not in punct_chars))

# %%
df['Body'] = df['Body'].str.replace('\n',' ')
df['Subject'] = df['Subject'].str.replace('\n',' ')
df['MostRecentMessage'] = df['MostRecentMessage'].str.replace('\n',' ')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115991 entries, 0 to 118797
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ModerationAction            115991 non-null  int64
#  1   Email_EmailId               115991 non-null  int64
#  2   GateKeeperModerationAction  115991 non-null  int64
#  3   ModuleType                  24068 non-null   float64
#  4   Sender                      115991 non-null  object
#  5   Recipient                   115991 non-null  object
#  6   Subject                     115991 non-null  object
#  7   Body                        115991 non-null  object
#  8   MostRecentMessage           115991 non-null  object
#  9   DateSent                    115991 non-null  datetime64[ns]
#  10  EmailStatus                 115991 non-null  float64
#  11  IPAddress                   115991 non-null  object
# ...

# %%
df['ModeratedOkay'] = df['ModerationAction'].apply(lambda x: 1 if x==3 else 0)

# %%
df.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  ModuleType  \
# 0                 6             25                           5         3.0
# 1                 6             28                           5         3.0
# 2                 6             31                           5         3.0
# 3                 3              1                           5         NaN
# 4                 3              7                           5         NaN
#
#                        Sender                          Recipient  \
# 0         deji90673@gmail.com              heidswood@hotmail.com
# 1         deji90673@gmail.com              promedia333@gmail.com
# 2         deji90673@gmail.com          hawkinsleslie69@yahoo.com
# 3                me@enuuu.com  marta.markow@fridaymediagroup.com
# 4  rebecca0607evans@gmail.com            herby432001@yahoo.co.uk
#
#                                              Subject  \
# 0  message regarding ad extremely reliable car fu...
# ...

# %%
df.ModeratedOkay.value_counts()
# Out:
# ModeratedOkay
# 1    106475
# 0      9516
# Name: count, dtype: int64

# %%
df_keyphrase = df[df['ModuleType'].isin([3, 4])]

# %%
df_keyphrase.drop(['ModuleType'],axis=1, inplace=True)

# %%
df_keyphrase.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  \
# 0                 6             25                           5
# 1                 6             28                           5
# 2                 6             31                           5
# 5                 6             46                           5
# 6                 6             49                           5
#
#                 Sender                  Recipient  \
# 0  deji90673@gmail.com      heidswood@hotmail.com
# 1  deji90673@gmail.com      promedia333@gmail.com
# 2  deji90673@gmail.com  hawkinsleslie69@yahoo.com
# 5  deji90673@gmail.com    kcscarsales@outlook.com
# 6  deji90673@gmail.com        andrewanr@gmail.com
#
#                                              Subject  \
# 0  message regarding ad extremely reliable car fu...
# 1          message regarding ad 2005 subaru forester
# 2  message regarding ad recently fully serviced n...
# 5  message regarding ad toyota rav4 petrol ulez c...
# ...

# %%
df_keyphrase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11006 entries, 0 to 118794
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ModerationAction            11006 non-null  int64
#  1   Email_EmailId               11006 non-null  int64
#  2   GateKeeperModerationAction  11006 non-null  int64
#  3   Sender                      11006 non-null  object
#  4   Recipient                   11006 non-null  object
#  5   Subject                     11006 non-null  object
#  6   Body                        11006 non-null  object
#  7   MostRecentMessage           11006 non-null  object
#  8   DateSent                    11006 non-null  datetime64[ns]
#  9   EmailStatus                 11006 non-null  float64
#  10  IPAddress                   11006 non-null  object
#  11  Country                     11006 non-null  object
#  12  OriginatingSiteId           11006 non-null  float64
# ...

# %%
df_fad = df_keyphrase[df_keyphrase['OriginatingSiteId']==1]
df_fad.drop(['SiteName','OriginatingSiteId'],axis=1, inplace=True)

# %%
df_fad.shape
# Out:
# (1945, 16)

# %% [markdown]
# # Lemmatization and One Hot Encoding

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

def lemmatize_text(text):
    if isinstance(text, str):
        words = text.split()
        lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
        return ' '.join(lemmatized_words)
    else:
        pass

# %%
df_fad[['Subject','Body','MostRecentMessage']] = df_fad[['Subject','Body','MostRecentMessage']].applymap(lemmatize_text)

# %%
df_fad.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  \
# 0                 6             25                           5
# 1                 6             28                           5
# 2                 6             31                           5
# 5                 6             46                           5
# 6                 6             49                           5
#
#                 Sender                  Recipient  \
# 0  deji90673@gmail.com      heidswood@hotmail.com
# 1  deji90673@gmail.com      promedia333@gmail.com
# 2  deji90673@gmail.com  hawkinsleslie69@yahoo.com
# 5  deji90673@gmail.com    kcscarsales@outlook.com
# 6  deji90673@gmail.com        andrewanr@gmail.com
#
#                                              Subject  \
# 0  message regarding ad extremely reliable car fu...
# 1          message regarding ad 2005 subaru forester
# 2  message regarding ad recently fully serviced n...
# 5  message regarding ad toyota rav4 petrol ulez c...
# ...

# %%
df_fad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1945 entries, 0 to 118780
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ModerationAction            1945 non-null   int64
#  1   Email_EmailId               1945 non-null   int64
#  2   GateKeeperModerationAction  1945 non-null   int64
#  3   Sender                      1945 non-null   object
#  4   Recipient                   1945 non-null   object
#  5   Subject                     1945 non-null   object
#  6   Body                        1945 non-null   object
#  7   MostRecentMessage           1945 non-null   object
#  8   DateSent                    1945 non-null   datetime64[ns]
#  9   EmailStatus                 1945 non-null   float64
#  10  IPAddress                   1945 non-null   object
#  11  Country                     1945 non-null   object
#  12  ThreadId                    1945 non-null   object
# ...

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from textblob import TextBlob, Word
from nltk.corpus import stopwords
import re

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rajathadri_as\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stpwrd = nltk.corpus.stopwords.words('english')

# %%
df_fad.head(2)
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  \
# 0                 6             25                           5
# 1                 6             28                           5
#
#                 Sender              Recipient  \
# 0  deji90673@gmail.com  heidswood@hotmail.com
# 1  deji90673@gmail.com  promedia333@gmail.com
#
#                                              Subject  \
# 0  message regarding ad extremely reliable car fu...
# 1          message regarding ad 2005 subaru forester
#
#                                                 Body  \
# 0  hi do you still have this available for sale p...
# 1  hi do you still have this available for sale p...
#
#                                    MostRecentMessage            DateSent  \
# 0  hi do you still have this available for sale p... 2023-07-19 06:05:18
# 1  hi do you still have this available for sale p... 2023-07-19 06:05:31
#
# ...

# %%
def remove_stopwords(text):
  text = [wd.lower() for wd in text.split() if wd.lower() not in stpwrd]
  return " ".join(text)

# %%
df_fad['Body'] = df_fad['Body'].apply(remove_stopwords)
df_fad['Subject'] = df_fad['Subject'].apply(remove_stopwords)
df_fad['MostRecentMessage'] = df_fad['MostRecentMessage'].apply(remove_stopwords)

# %%
df_fad.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  \
# 0                 6             25                           5
# 1                 6             28                           5
# 2                 6             31                           5
# 5                 6             46                           5
# 6                 6             49                           5
#
#                 Sender                  Recipient  \
# 0  deji90673@gmail.com      heidswood@hotmail.com
# 1  deji90673@gmail.com      promedia333@gmail.com
# 2  deji90673@gmail.com  hawkinsleslie69@yahoo.com
# 5  deji90673@gmail.com    kcscarsales@outlook.com
# 6  deji90673@gmail.com        andrewanr@gmail.com
#
#                                              Subject  \
# 0  message regarding ad extremely reliable car fu...
# 1          message regarding ad 2005 subaru forester
# 2  message regarding ad recently fully serviced n...
# 5  message regarding ad toyota rav4 petrol ulez c...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(stop_words=stpwrd)

# %%
counts = count_vectorizer.fit_transform(df_fad['Body'])

# %%
counts_df =  pd.DataFrame(counts.toarray(), columns = count_vectorizer.get_feature_names_out())

# %%
counts_df.shape
# Out:
# (1945, 8009)

# %%
counts_dict = {}

# Store the words as key-value pairs
for ii, word in enumerate(counts_df.columns):
    counts_dict[word] = sum(counts_df[str(word)])
    word_count = [(i,count) for i,count in list(zip(counts_dict.keys(), counts_dict.values()))]

# %%
sorted_counts = sorted(word_count, key = lambda x: x[1], reverse = True)
sorted_counts[:35]
# Out:
# [('email', 1413),
#  ('registered', 929),
#  ('sent', 911),
#  ('reply', 737),
#  ('hi', 716),
#  ('fridayad', 688),
#  ('message', 554),
#  ('please', 545),
#  ('hello', 536),
#  ('respond', 529),
#  ('number', 471),
#  ('sussex', 471),
#  ('dont', 470),
#  ('good', 451),
#  ('im', 444),
#  ('address', 430),
#  ('would', 411),
#  ('available', 408),
#  ('ad', 397),
#  ('wa', 394),
#  ('like', 384),
#  ('company', 370),
#  ('ha', 368),
#  ('friday', 367),
#  ('west', 363),
#  ('massage', 352),
#  ('user', 350),
#  ('visit', 343),
#  ('office', 341),
#  ('road', 337),
#  ('2023', 336),
#  ('london', 328),
#  ('part', 328),
#  ('miss', 325),
#  ('england', 318)]

# %%
add_stopwords = ['2023', 'ha', 'wa' ,'west', 'ad', 'friday','dont','thanks','would','good','sussex','message','respond','available','please','hello','still','reply','fridayad','sent','registered','hi','email']

# %%
#Function to remove additional stopwords 
def remove_add_stopwords(text):
  text = [wd.lower() for wd in text.split() if wd.lower() not in add_stopwords]
  return " ".join(text)

# %%
df_fad['Body'] = df_fad['Body'].apply(remove_add_stopwords)
df_fad['Subject'] = df_fad['Subject'].apply(remove_add_stopwords)
df_fad['MostRecentMessage'] = df_fad['MostRecentMessage'].apply(remove_add_stopwords)

# %%
df_fad.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  \
# 0                 6             25                           5
# 1                 6             28                           5
# 2                 6             31                           5
# 5                 6             46                           5
# 6                 6             49                           5
#
#                 Sender                  Recipient  \
# 0  deji90673@gmail.com      heidswood@hotmail.com
# 1  deji90673@gmail.com      promedia333@gmail.com
# 2  deji90673@gmail.com  hawkinsleslie69@yahoo.com
# 5  deji90673@gmail.com    kcscarsales@outlook.com
# 6  deji90673@gmail.com        andrewanr@gmail.com
#
#                                              Subject  \
# 0  regarding extremely reliable car full year mot...
# 1                     regarding 2005 subaru forester
# 2  regarding recently fully serviced new brake di...
# 5        regarding toyota rav4 petrol ulez compliant
# ...

# %%
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
count = CountVectorizer()
word_count=count.fit_transform(df_fad.Body)
word_count.shape
# Out:
# (1945, 8012)

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
tfidf_transformer.fit(word_count)
df_idf = pd.DataFrame(tfidf_transformer.idf_, index=count.get_feature_names_out(),columns=["idf_weights"])

# %%
tf_idf_vector=tfidf_transformer.transform(word_count)
feature_names = count.get_feature_names_out()
first_document_vector=tf_idf_vector[1]
df_tfifd= pd.DataFrame(first_document_vector.T.todense(), index=feature_names, columns=["tfidf"])

# %%
df_fad.head()
# Out:
#    ModerationAction  Email_EmailId  GateKeeperModerationAction  \
# 0                 6             25                           5
# 1                 6             28                           5
# 2                 6             31                           5
# 5                 6             46                           5
# 6                 6             49                           5
#
#                 Sender                  Recipient  \
# 0  deji90673@gmail.com      heidswood@hotmail.com
# 1  deji90673@gmail.com      promedia333@gmail.com
# 2  deji90673@gmail.com  hawkinsleslie69@yahoo.com
# 5  deji90673@gmail.com    kcscarsales@outlook.com
# 6  deji90673@gmail.com        andrewanr@gmail.com
#
#                                              Subject  \
# 0  regarding extremely reliable car full year mot...
# 1                     regarding 2005 subaru forester
# 2  regarding recently fully serviced new brake di...
# 5        regarding toyota rav4 petrol ulez compliant
# ...

# %%
X = df_fad.drop(['ModeratedOkay'], axis = 1)
y = df_fad['ModeratedOkay']

# %%
X.shape
# Out:
# (1945, 15)

# %%
y.shape
# Out:
# (1945,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test , y_train, y_test = train_test_split(df_fad['Body'].values,df_fad['ModeratedOkay'].values,test_size=0.2,random_state=123,stratify=df_fad['ModerationAction'].values)

# %%
tfidf_vectorizer = TfidfVectorizer() 

tfidf_train_vectors = tfidf_vectorizer.fit_transform(X_train)

tfidf_test_vectors = tfidf_vectorizer.transform(X_test)

# %%
import pickle

# %%
# Save the model to a file using pickle
tfidf_file = 'tfidf_vectorizer.pkl'
with open(tfidf_file, 'wb') as file:
    pickle.dump(tfidf_vectorizer, file)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier = RandomForestClassifier()

classifier.fit(tfidf_train_vectors,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = classifier.predict(tfidf_test_vectors)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93        58
#            1       0.98      0.99      0.99       331
#
#     accuracy                           0.98       389
#    macro avg       0.97      0.95      0.96       389
# weighted avg       0.98      0.98      0.98       389

# %% [markdown]
# # Predictions

# %%
model = RandomForestClassifier()

model.fit(tfidf_train_vectors, y_train)

# Save the model to a file using pickle
filename = 'randomfrst_model.pkl'
with open(filename, 'wb') as file:
    pickle.dump(model, file)

# %%
X_test[6]
# Out:
# 'im 29 year old man completed cscs course past 2 year construction experience full clean manual driving license like keep busy looking full time work also strong love art love opportunity get know young man conversation art general currently date cv wanted submit interest role immediately willing answer question may feel free give call 07831 341596 alexbart316gmailcom look forward hearing kind regard alex bartholomew'

# %%
y_test[3]
# Out:
# 1

# %%
indices = np.where(y_test == 0)
indices
# Out:
# (array([  6,  23,  24,  31,  47,  49,  55,  68,  72,  87,  91,  92, 112,
#         113, 129, 132, 148, 172, 177, 180, 187, 189, 192, 210, 215, 217,
#         226, 228, 241, 242, 246, 247, 256, 258, 259, 261, 267, 270, 273,
#         283, 285, 286, 291, 295, 299, 311, 315, 318, 320, 345, 346, 351,
#         355, 356, 365, 371, 378, 381], dtype=int64),)

# %%
# Load the File and predict unseen data

filename = 'randomfrst_model.pkl'

with open(filename, 'rb') as file:
    mod = pickle.load(file)

# %%
# Load some new data for prediction
input_text = 'im 29 year old man completed cscs course past 2 year construction experience full clean manual driving license like keep busy looking full time work also strong love art love opportunity get know young man conversation art general currently date cv wanted submit interest role immediately willing answer question may feel free give call 07831 341596 alexbart316gmailcom look forward hearing kind regard alex bartholomew'

# %%
# Load the TF-IDF Vectorizer Used During Training
with open(tfidf_file, 'rb') as vectorizer_file:
    tfidf_vectorizer = pickle.load(vectorizer_file)

# %%
# Transform the Input Text Using the Vectorizer
input_vector = tfidf_vectorizer.transform([input_text])

# %%
# Make Predictions
predicted_category = mod.predict(input_vector)
probability_scores = mod.predict_proba(input_vector)

# %%
# Print the Predictions
print("Moderated Okay:", predicted_category)
print("Probability Scores:", probability_scores)
# Out:
# Moderated Okay: [0]
# Probability Scores: [[0.8 0.2]]
